# %%
import torch
import time
from script.NeuralNets.Networks import SequentialNN
from script.settings import device, data_type
import script.DHOV.MultiDHOV as multidhov
from script.Verification.Verifier import SingleNeuronVerifier, MILPVerifier
import gurobipy as grp
from torchvision.datasets import MNIST
from torchvision.transforms import Compose, ToTensor, Normalize
from script.NeuralNets.ICNNFactory import ICNNFactory
import matplotlib.pyplot as plt
from script import eval

# %%
def add_output_constraints(model, nn_layer_out_bounds, label, output_vars, sovler_bound=1e-3):
    out_lb = nn_layer_out_bounds[-1][0]
    out_ub = nn_layer_out_bounds[-1][1]
    difference_lb = out_lb - out_ub[label]
    difference_ub = out_ub - out_lb[label]
    difference_lb = difference_lb.tolist()
    difference_ub = difference_ub.tolist()
    difference_lb.pop(label)
    difference_ub.pop(label)
    min_diff = min(difference_lb)
    max_diff = max(difference_ub)

    difference = model.addVars(9, lb=difference_lb, ub=difference_ub, name="diff_var")
    model.addConstrs((difference[i] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(0, label)), name="diff_const0")
    model.addConstrs((difference[i - 1] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(label + 1, 10)), name="diff_const1")

    max_var = model.addVar(lb=min_diff, ub=max_diff, name="max_var")
    model.addConstr(max_var == grp.max_(difference))

    if sovler_bound != None:
        model.setParam("BestObjStop", sovler_bound)

    model.update()
    model.setObjective(max_var, grp.GRB.MAXIMIZE)

# %%
def get_output_vars_snv_milp(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("affine_var{}[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def get_output_vars_dhov(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("output_layer_[{}]_[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def optimize_model(model, output_vars):
    start = time.time()
    model.update()
    model.optimize()
    if model.Status == grp.GRB.OPTIMAL or model.Status == grp.GRB.USER_OBJ_LIMIT:
        for i, var in enumerate(output_vars.tolist()):
            print("var {}: {}".format(i, var.getAttr("x")))
        max_var = model.getVarByName("max_var").getAttr("x")
        if max_var < 0:
            print("property verified with max difference {}".format(max_var))
            return True
        else:
             print("property NOT verified with max difference {}".format(max_var))
             return False

    elif model.Status == grp.GRB.INFEASIBLE:
        print("model infeasible")

        model.computeIIS()
        print("constraint")
        all_constr = model.getConstrs()

        for const in all_constr:
            if const.IISConstr:
                print("{}".format(const))

        print("lower bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISLB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

        print("upper bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISUB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

    print("time to optimize: {}".format(time.time() - start))
    return False

# %%
transform = Compose([ToTensor(),  Normalize(0.5, 0.5)])
training_data = MNIST(root="../../mnist", train=True, download=True, transform=transform)

nn = SequentialNN([28 * 28 * 1, 256, 256, 256, 256, 10])
nn.load_state_dict(torch.load("../../mnist_fc 4x256.pth", map_location=torch.device('cpu')), strict=False)
parameter_list = list(nn.parameters())
output_size = 10
number_layer = (len(parameter_list) - 2) // 2

eps = 0.026
samples_to_verify_count = 50

# %% [markdown]
# DHOV

# %% [markdown]
# SNR

# %%
snr_verifier_list = []
not_verified_index_snr = []
sample_index = 40
round_index = 0
while sample_index < samples_to_verify_count:
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    simple_bounds_affine_out, simple_bounds_layer_out = nn.calculate_box_bounds([input_flattened.add(-eps), input_flattened.add(eps)])

    if not torch.argmax(nn(torch_image)).item() == label:
        sample_index += 1
        continue
    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_count-1, sample_index))

    overall_time = time.time()
    snv_verifier = SingleNeuronVerifier(nn, torch_image, eps, print_log=False, print_new_bounds=False, optimize_bounds=True)
    snv_verifier.generate_constraints_for_net()
    snr_verifier_list.append(snv_verifier)
    snv_model = snv_verifier.model.copy()
    snv_model.update()
    snv_out_vars = get_output_vars_snv_milp(snv_model, output_size, number_layer * 2)
    add_output_constraints(snv_model, simple_bounds_layer_out, label, snv_out_vars, sovler_bound=None)

    print("start with optimization")
    successful_ver = optimize_model(snv_model, snv_out_vars)
    if not successful_ver:
        not_verified_index_snr.append((sample_index, round_index))
    print("overall time: {}".format(time.time() - overall_time))

    round_index += 1
    sample_index += 1
# Out:
# 0/49 | image index 40 ===========================================================================================
# start with optimization
# var 0: -7.418198921073439
# var 1: 7.451668900662782
# var 2: -0.3882476256098384
# var 3: 1.789417360199626
# var 4: -1.1221665558078042
# var 5: -1.1631770121091334
# var 6: -2.9622329985697826
# var 7: -0.096712371024533
# var 8: 5.63986897637917
# var 9: 0.5211948392221872
# property verified with max difference -1.811799924283612
# overall time: 445.9088499546051
# 1/49 | image index 41 ===========================================================================================
# start with optimization
# var 0: -3.697307265499136
# var 1: 1.88903549825306
# var 2: 0.7894722372768914
# var 3: 5.097959687334179
# var 4: -4.870761160993947
# var 5: 0.9083023134253763
# var 6: -6.182785935165191
# var 7: -3.238230998512689
# var 8: 8.817070122347245
# var 9: 2.1167444019455397
# property verified with max difference -3.7191104350130653
# overall time: 356.4559142589569
# 2/49 | image index 42 ===========================================================================================
# start with optimization
# var 0: -5.025606590107241
# var 1: 0.8650736632240044
# var 2: -1.8505968939146094
# var 3: 2.6616687775769208
# var 4: -2.042498821288138
# var 5: 2.250202382602737
# var 6: -8.47942878952136
# var 7: 2.723539828694161
# var 8: 3.463522635861377
# var 9: 6.16156844312362
# property NOT verified with max difference 3.4380286144294594
# overall time: 581.722541809082
# 3/49 | image index 43 ===========================================================================================
# start with optimization
# var 0: -6.907894626880275
# var 1: 2.0715104781081575
# var 2: -2.00721575574026
# var 3: 6.369952606156358
# var 4: -0.8977330280679263
# var 5: 1.0308720589650378
# var 6: -10.480722624323064
# var 7: 3.2105073466095178
# var 8: 3.0313864520563483
# var 9: 6.3427852534280476
# property NOT verified with max difference 0.027167352728310352
# overall time: 515.8767669200897
# 4/49 | image index 44 ===========================================================================================
# start with optimization
# var 0: -5.865768674550754
# var 1: 4.134446315722412
# var 2: 4.276786525167292
# var 3: 9.621440147713281
# var 4: -5.81510203331657
# var 5: -0.4371372908006048
# var 6: -10.959728978319403
# var 7: 5.876665347375885
# var 8: 1.0972947562567796
# var 9: 1.3802907809757752
# property verified with max difference -3.744774800337396
# overall time: 489.16192746162415
# 5/49 | image index 45 ===========================================================================================
# start with optimization
# var 0: -4.00001491160663
# var 1: -5.113842057940403
# var 2: -3.587617349769781
# var 3: 2.65733077971654
# var 4: 1.3748789504590704
# var 5: 3.3819948223415484
# var 6: -10.135402871685791
# var 7: -1.322582313006471
# var 8: 7.395443645607493
# var 9: 9.082328977502023
# property verified with max difference -1.6868853318945298
# overall time: 467.5873055458069
# 6/49 | image index 46 ===========================================================================================
# start with optimization
# var 0: 1.0219442147713496
# var 1: -0.25925376307242853
# var 2: 6.701383328545444
# var 3: 3.96364972489697
# var 4: -10.044062277951536
# var 5: 1.4393054709722906
# var 6: -4.959982759806766
# var 7: -1.3847101878276744
# var 8: 6.476750793993529
# var 9: -1.5915456121349818
# property NOT verified with max difference 0.22463253455191534
# overall time: 403.08920097351074
# 7/49 | image index 47 ===========================================================================================
# start with optimization
# var 0: -2.5026168406325358
# var 1: -1.2444565690457132
# var 2: -4.058376319734666
# var 3: 0.49287946187269505
# var 4: -0.20051110462109278
# var 5: 10.960104602035125
# var 6: -0.24888510490802673
# var 7: -6.646020112202132
# var 8: 5.729968900321451
# var 9: -1.6960380814158498
# property verified with max difference -5.2301357017136745
# overall time: 215.44271230697632
# 8/49 | image index 48 ===========================================================================================
# start with optimization
# var 0: -5.1001921873618965
# var 1: 2.460225820890825
# var 2: -3.6700631704317415
# var 3: 4.186099639921323
# var 4: -2.8029211861700487
# var 5: 6.605002881045438
# var 6: -4.611725703371561
# var 7: -1.498586130531499
# var 8: 3.709031625089831
# var 9: 2.188431260171474
# property NOT verified with max difference 4.416571620873964
# overall time: 233.73379707336426
# 9/49 | image index 49 ===========================================================================================
# start with optimization
# var 0: -1.929752892932644
# var 1: 1.4379522889300027
# var 2: -2.2416843943752127
# var 3: 10.456842648168426
# var 4: -9.216084422201746
# var 5: 9.924875433244358
# var 6: -7.621734962489345
# var 7: -5.242203752262309
# var 8: 4.7896598046264245
# var 9: 1.9175584581653489
# property verified with max difference -0.5319672149240677
# overall time: 167.73766350746155

# %%
print(not_verified_index_snr)
# Out:
# [(42, 2), (43, 3), (46, 6), (48, 8)]

# %%
not_verified_index_snr = [(33, 3), (38, 8), (42,2)]

# %%
group_size = 20
sample_count = 1000
sampling_method = "per_group_sampling"
net_size = [5, 1]
icnn_factory = ICNNFactory("logical", net_size, always_use_logical_layer=False)
#icnn_factory = ICNNFactory("standard", net_size, adapt_layer_for_init=True)
#icnn_factory = ICNNFactory("approx_max", net_size, maximum_function="SMU", function_parameter=0.3)

dhov_verifier_list = []
not_verified_index_dhov = []
sample_index = 0
round_index = 0
samples_to_verify_dhov = len(not_verified_index_snr)
for touple in not_verified_index_snr:
    sample_index = touple[0]
    round_index = touple[1]
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    #bounds_affine_out_snr, bounds_layer_out_snr = snr_verifier_list[round_index].bounds_affine_out, snr_verifier_list[round_index].bounds_layer_out
    bounds_affine_out_snr, bounds_layer_out_snr = None, None

    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_dhov-1, sample_index))


    overall_time = time.time()
    dhov_verifier = multidhov.MultiDHOV()
    dhov_verifier.start_verification(nn, torch_image, icnn_factory, group_size, eps=eps, icnn_epochs=200, init_affine_bounds=bounds_affine_out_snr, init_layer_bounds=bounds_layer_out_snr,
                                     icnn_batch_size=10000, sample_count=sample_count, sample_new=True, use_over_approximation=True, break_after=None,
                                     sample_over_input_space=False, sample_over_output_space=True, tighten_bounds=True,
                                     use_fixed_neurons_in_grouping=False, sampling_method=sampling_method, layers_as_snr=[], layers_as_milp=[3],
                                     force_inclusion_steps=3, preemptive_stop=True, even_gradient_training=False,
                                     keep_ambient_space=False, data_grad_descent_steps=0, opt_steps_gd=100,
                                     train_outer=False, print_training_loss=False, print_new_bounds=False,
                                     grouping_method="consecutive", group_num_multiplier=5, store_samples=False, print_optimization_steps=False, print_last_loss=False,
                                     should_plot="none", optimizer="SdLBFGS", init_network=True, adapt_lambda="included")


    dhov_verifier_list.append(dhov_verifier)

    dhov_model = dhov_verifier.nn_encoding_model.copy()
    dhov_model.update()
    dhov_out_vars = get_output_vars_dhov(dhov_model, output_size, number_layer)
    add_output_constraints(dhov_model, dhov_verifier.bounds_layer_out, label, dhov_out_vars, sovler_bound=float("inf"))
    successful_ver = optimize_model(dhov_model, dhov_out_vars)
    if not successful_ver:
        not_verified_index_dhov.append(sample_index)
    print("overall time: {}".format(time.time() - overall_time))
    round_index += 1
    sample_index += 1
# Out:
# 3/2 | image index 33 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 175
#     layer progress, group 1 of 5
#         time for sampling for one group: 0.2010021209716797
#         time for training: 11.248317956924438
#         actual verification time 3.995626211166382
#         time for verification: 4.2656378746032715
#     layer progress, group 2 of 5
#         time for sampling for one group: 0.11700105667114258
#         time for training: 16.284287929534912
#         actual verification time 1.4881625175476074
#         time for verification: 1.747161626815796
#     layer progress, group 3 of 5
#         time for sampling for one group: 0.11600017547607422
#         time for training: 12.405704736709595
#         actual verification time 1.2061471939086914
#         time for verification: 1.448145866394043
#     layer progress, group 4 of 5
#         time for sampling for one group: 0.11300110816955566
#         time for training: 12.408117532730103
#         actual verification time 1.3225667476654053
#         time for verification: 1.576611042022705
#     layer progress, group 5 of 5
#         time for sampling for one group: 0.02200150489807129
#         time for training: 14.295965433120728
#         actual verification time 0.003006458282470703
#         time for verification: 0.0529942512512207
#
# approximation of layer: 1
#     time for icnn_bound calculation: 41.525054931640625
#     number of fixed neurons for current layer: 178
#     layer progress, group 1 of 4
#         time for sampling for one group: 54.641382932662964
#         time for training: 12.100740909576416
#         actual verification time 21.411198377609253
#         time for verification: 21.77019739151001
#     layer progress, group 2 of 4
#         time for sampling for one group: 50.43691420555115
#         time for training: 12.231200456619263
#         actual verification time 10.734402179718018
#         time for verification: 10.995403289794922
#     layer progress, group 3 of 4
#         time for sampling for one group: 62.720070362091064
#         time for training: 9.232969999313354
#         actual verification time 23.06700301170349
#         time for verification: 23.307002544403076
#     layer progress, group 4 of 4
#         time for sampling for one group: 43.970221519470215
#         time for training: 9.247250080108643
#         actual verification time 35.052135705947876
#         time for verification: 35.2311487197876
#
# approximation of layer: 2
#     time for icnn_bound calculation: 226.11676287651062
#     number of fixed neurons for current layer: 186
#     layer progress, group 1 of 4
#         time for sampling for one group: 148.71965098381042
#         time for training: 14.761889219284058
#         actual verification time 14.995734453201294
#         time for verification: 15.266780853271484
#     layer progress, group 2 of 4
#         time for sampling for one group: 181.32394337654114
#         time for training: 14.281400203704834
#         actual verification time 54.63349366188049
#         time for verification: 54.93213224411011
#     layer progress, group 3 of 4
#         time for sampling for one group: 221.21925854682922
#         time for training: 6.643894910812378
#         actual verification time 72.34687304496765
#         time for verification: 72.55193996429443
#     layer progress, group 4 of 4
#         time for sampling for one group: 185.96304631233215
#         time for training: 15.516626358032227
#         actual verification time 9.274247646331787
#         time for verification: 9.4502534866333
#
# approximation of layer: 3
#     time for icnn_bound calculation: 709.6073176860809
#     number of fixed neurons for current layer: 179
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.012999534606933594
# done...
# var 0: -5.1221450053888455
# var 1: 0.9164000932135457
# var 2: -0.85227728037232
# var 3: 3.921705415611968
# var 4: 0.0688259635414541
# var 5: -1.3246921946155643
# var 6: -10.462105327663561
# var 7: 7.593701832002831
# var 8: -0.014452873197576821
# var 9: 6.292972250663182
# property NOT verified with max difference 1.3007295813396487
# overall time: 2421.6871778964996
# 8/2 | image index 38 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 177
#     layer progress, group 1 of 4
#         time for sampling for one group: 0.1219949722290039
#         time for training: 6.810136079788208
#         actual verification time 1.8692784309387207
#         time for verification: 2.099282741546631
#     layer progress, group 2 of 4
#         time for sampling for one group: 0.11699748039245605
#         time for training: 6.616948843002319
#         actual verification time 1.9203884601593018
#         time for verification: 2.1719319820404053
#     layer progress, group 3 of 4
#         time for sampling for one group: 0.11100649833679199
#         time for training: 5.969461679458618
#         actual verification time 1.815378189086914
#         time for verification: 2.004385232925415
#     layer progress, group 4 of 4
#         time for sampling for one group: 0.08800196647644043
#         time for training: 5.051320552825928
#         actual verification time 1.8029780387878418
#         time for verification: 1.9839811325073242
#
# approximation of layer: 1
#     time for icnn_bound calculation: 33.42072868347168
#     number of fixed neurons for current layer: 175
#     layer progress, group 1 of 5
#         time for sampling for one group: 32.420233964920044
#         time for training: 11.889987230300903
#         actual verification time 8.783681154251099
#         time for verification: 8.9936842918396
#     layer progress, group 2 of 5
#         time for sampling for one group: 31.351186513900757
#         time for training: 9.066963911056519
#         actual verification time 10.561888217926025
#         time for verification: 10.78390645980835
#     layer progress, group 3 of 5
#         time for sampling for one group: 37.819286584854126
#         time for training: 11.105374097824097
#         actual verification time 49.57331466674805
#         time for verification: 49.825382471084595
#     layer progress, group 4 of 5
#         time for sampling for one group: 43.003093242645264
#         time for training: 7.290674448013306
#         actual verification time 9.140784978866577
#         time for verification: 9.420799493789673
#     layer progress, group 5 of 5
#         time for sampling for one group: 36.084245920181274
#         time for training: 13.013437747955322
#         actual verification time 1.1140127182006836
#         time for verification: 1.1510112285614014
#
# approximation of layer: 2
#     time for icnn_bound calculation: 186.2957046031952
#     number of fixed neurons for current layer: 189
#     layer progress, group 1 of 4
#         time for sampling for one group: 203.73429918289185
#         time for training: 29.247485637664795
#         actual verification time 117.68370580673218
#         time for verification: 117.93170142173767
#     layer progress, group 2 of 4
#         time for sampling for one group: 185.3904013633728
#         time for training: 5.774811267852783
#         actual verification time 23.35872173309326
#         time for verification: 23.560314893722534
#     layer progress, group 3 of 4
#         time for sampling for one group: 171.10847663879395
#         time for training: 14.298577547073364
#         actual verification time 118.85811686515808
#         time for verification: 119.06413221359253
#     layer progress, group 4 of 4
#         time for sampling for one group: 195.98884415626526
#         time for training: 17.119069576263428
#         actual verification time 8.711577892303467
#         time for verification: 8.843587875366211
#
# approximation of layer: 3
#     time for icnn_bound calculation: 619.2584869861603
#     number of fixed neurons for current layer: 169
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.013004064559936523
# done...
# var 0: -2.7202480239919202
# var 1: 0.6668465656280373
# var 2: 8.613073240844864
# var 3: 3.8983135967889284
# var 4: -1.986623431023948
# var 5: -4.858716900359252
# var 6: -6.0023911109087065
# var 7: 7.633376590018789
# var 8: -2.655731089851275
# var 9: -0.8744635087070671
# property NOT verified with max difference 0.9796966508260752
# overall time: 2357.864781141281
# 2/2 | image index 42 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 151
#     layer progress, group 1 of 6
#         time for sampling for one group: 0.13157200813293457
#         time for training: 5.800162076950073
#         actual verification time 2.0171546936035156
#         time for verification: 2.232161045074463
#     layer progress, group 2 of 6
#         time for sampling for one group: 0.09899377822875977
#         time for training: 4.892191171646118
#         actual verification time 1.0569963455200195
#         time for verification: 1.2779407501220703
#     layer progress, group 3 of 6
#         time for sampling for one group: 0.09600019454956055
#         time for training: 5.391928672790527
#         actual verification time 1.6110661029815674
#         time for verification: 1.8110675811767578
#     layer progress, group 4 of 6
#         time for sampling for one group: 0.09300398826599121
#         time for training: 4.849412202835083
#         actual verification time 1.4480669498443604
#         time for verification: 1.6460812091827393
#     layer progress, group 5 of 6
#         time for sampling for one group: 0.10741496086120605
#         time for training: 5.381109237670898
#         actual verification time 4.208064317703247
#         time for verification: 4.443147897720337
#     layer progress, group 6 of 6
#         time for sampling for one group: 0.037003517150878906
#         time for training: 14.322816848754883
#         actual verification time 0.0769948959350586
#         time for verification: 0.1789994239807129
#
# approximation of layer: 1
#     time for icnn_bound calculation: 68.89376163482666
#     number of fixed neurons for current layer: 158
#     layer progress, group 1 of 5
#         time for sampling for one group: 53.578843116760254
#         time for training: 6.080127477645874
#         actual verification time 19.47244095802307
#         time for verification: 19.731444597244263
#     layer progress, group 2 of 5
#         time for sampling for one group: 53.6462025642395
#         time for training: 7.269704818725586
#         actual verification time 23.441843509674072
#         time for verification: 23.643433332443237
#     layer progress, group 3 of 5
#         time for sampling for one group: 89.30360436439514
#         time for training: 12.056591510772705
#         actual verification time 41.707640647888184
#         time for verification: 41.970189809799194
#     layer progress, group 4 of 5
#         time for sampling for one group: 74.32505226135254
#         time for training: 12.337074995040894
#         actual verification time 18.58327841758728
#         time for verification: 18.930365085601807
#     layer progress, group 5 of 5
#         time for sampling for one group: 50.97055649757385
#         time for training: 4.709280490875244
#         actual verification time 21.37911629676819
#         time for verification: 21.575113773345947
#
# approximation of layer: 2
#     time for icnn_bound calculation: 295.2809820175171
#     number of fixed neurons for current layer: 177
#     layer progress, group 1 of 4
#         time for sampling for one group: 294.73765540122986
#         time for training: 78.86014914512634
#         actual verification time 180.36822938919067
#         time for verification: 180.6472306251526
#     layer progress, group 2 of 4
#         time for sampling for one group: 304.39289116859436
#         time for training: 6.5600597858428955
#         actual verification time 37.11977005004883
#         time for verification: 37.331787109375
#     layer progress, group 3 of 4
#         time for sampling for one group: 308.1013231277466
#         time for training: 5.467483758926392
#         actual verification time 20.002068996429443
#         time for verification: 20.204071044921875
#     layer progress, group 4 of 4
#         time for sampling for one group: 242.94906544685364
#         time for training: 10.235331773757935
#         actual verification time 58.967530727386475
#         time for verification: 59.22754693031311
#
# approximation of layer: 3
#     time for icnn_bound calculation: 679.5206272602081
#     number of fixed neurons for current layer: 159
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.00599360466003418
# done...
# var 0: -3.851083056533368
# var 1: 1.5370839949884871
# var 2: -0.2952637900736841
# var 3: 1.9976927383972596
# var 4: -4.098454934503483
# var 5: 2.104516367384773
# var 6: -7.284502934217601
# var 7: 2.604377968382257
# var 8: 5.06351102455123
# var 9: 3.1868956066809346
# property NOT verified with max difference 2.4591330561689726
# overall time: 3180.61119222641
