# %%
import torch
import time
from script.NeuralNets.Networks import SequentialNN
from script.settings import device, data_type
import script.DHOV.MultiDHOV as multidhov
from script.Verification.Verifier import SingleNeuronVerifier, MILPVerifier
import gurobipy as grp
from torchvision.datasets import MNIST
from torchvision.transforms import Compose, ToTensor, Normalize
from script.NeuralNets.ICNNFactory import ICNNFactory
import matplotlib.pyplot as plt
from script import eval

# %%
def add_output_constraints(model, nn_layer_out_bounds, label, output_vars, sovler_bound=1e-3):
    out_lb = nn_layer_out_bounds[-1][0]
    out_ub = nn_layer_out_bounds[-1][1]
    difference_lb = out_lb - out_ub[label]
    difference_ub = out_ub - out_lb[label]
    difference_lb = difference_lb.tolist()
    difference_ub = difference_ub.tolist()
    difference_lb.pop(label)
    difference_ub.pop(label)
    min_diff = min(difference_lb)
    max_diff = max(difference_ub)

    difference = model.addVars(9, lb=difference_lb, ub=difference_ub, name="diff_var")
    model.addConstrs((difference[i] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(0, label)), name="diff_const0")
    model.addConstrs((difference[i - 1] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(label + 1, 10)), name="diff_const1")

    max_var = model.addVar(lb=min_diff, ub=max_diff, name="max_var")
    model.addConstr(max_var == grp.max_(difference))

    if sovler_bound != None:
        model.setParam("BestObjStop", sovler_bound)

    model.update()
    model.setObjective(max_var, grp.GRB.MAXIMIZE)

# %%
def get_output_vars_snv_milp(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("affine_var{}[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def get_output_vars_dhov(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("output_layer_[{}]_[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def optimize_model(model, output_vars):
    start = time.time()
    model.update()
    model.optimize()
    if model.Status == grp.GRB.OPTIMAL or model.Status == grp.GRB.USER_OBJ_LIMIT:
        for i, var in enumerate(output_vars.tolist()):
            print("var {}: {}".format(i, var.getAttr("x")))
        max_var = model.getVarByName("max_var").getAttr("x")
        if max_var < 0:
            print("property verified with max difference {}".format(max_var))
            return True
        else:
             print("property NOT verified with max difference {}".format(max_var))
             return False

    elif model.Status == grp.GRB.INFEASIBLE:
        print("model infeasible")

        model.computeIIS()
        print("constraint")
        all_constr = model.getConstrs()

        for const in all_constr:
            if const.IISConstr:
                print("{}".format(const))

        print("lower bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISLB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

        print("upper bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISUB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

    print("time to optimize: {}".format(time.time() - start))
    return False

# %%
transform = Compose([ToTensor(),  Normalize(0.5, 0.5)])
training_data = MNIST(root="../../mnist", train=True, download=True, transform=transform)

nn = SequentialNN([28 * 28 * 1, 256, 256, 256, 256, 10])
nn.load_state_dict(torch.load("../../mnist_fc 4x256.pth", map_location=torch.device('cpu')), strict=False)
parameter_list = list(nn.parameters())
output_size = 10
number_layer = (len(parameter_list) - 2) // 2

eps = 0.026
samples_to_verify_count = 50

# %% [markdown]
# DHOV

# %% [markdown]
# SNR

# %%
snr_verifier_list = []
not_verified_index_snr = []
sample_index = 40
round_index = 0
while sample_index < samples_to_verify_count:
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    simple_bounds_affine_out, simple_bounds_layer_out = nn.calculate_box_bounds([input_flattened.add(-eps), input_flattened.add(eps)])

    if not torch.argmax(nn(torch_image)).item() == label:
        sample_index += 1
        continue
    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_count-1, sample_index))

    overall_time = time.time()
    snv_verifier = SingleNeuronVerifier(nn, torch_image, eps, print_log=False, print_new_bounds=False, optimize_bounds=True)
    snv_verifier.generate_constraints_for_net()
    snr_verifier_list.append(snv_verifier)
    snv_model = snv_verifier.model.copy()
    snv_model.update()
    snv_out_vars = get_output_vars_snv_milp(snv_model, output_size, number_layer * 2)
    add_output_constraints(snv_model, simple_bounds_layer_out, label, snv_out_vars, sovler_bound=None)

    print("start with optimization")
    successful_ver = optimize_model(snv_model, snv_out_vars)
    if not successful_ver:
        not_verified_index_snr.append((sample_index, round_index))
    print("overall time: {}".format(time.time() - overall_time))

    round_index += 1
    sample_index += 1
# Out:
# 0/49 | image index 40 ===========================================================================================
# start with optimization
# var 0: -7.418198921073439
# var 1: 7.451668900662782
# var 2: -0.3882476256098384
# var 3: 1.789417360199626
# var 4: -1.1221665558078042
# var 5: -1.1631770121091334
# var 6: -2.9622329985697826
# var 7: -0.096712371024533
# var 8: 5.63986897637917
# var 9: 0.5211948392221872
# property verified with max difference -1.811799924283612
# overall time: 445.9088499546051
# 1/49 | image index 41 ===========================================================================================
# start with optimization
# var 0: -3.697307265499136
# var 1: 1.88903549825306
# var 2: 0.7894722372768914
# var 3: 5.097959687334179
# var 4: -4.870761160993947
# var 5: 0.9083023134253763
# var 6: -6.182785935165191
# var 7: -3.238230998512689
# var 8: 8.817070122347245
# var 9: 2.1167444019455397
# property verified with max difference -3.7191104350130653
# overall time: 356.4559142589569
# 2/49 | image index 42 ===========================================================================================
# start with optimization
# var 0: -5.025606590107241
# var 1: 0.8650736632240044
# var 2: -1.8505968939146094
# var 3: 2.6616687775769208
# var 4: -2.042498821288138
# var 5: 2.250202382602737
# var 6: -8.47942878952136
# var 7: 2.723539828694161
# var 8: 3.463522635861377
# var 9: 6.16156844312362
# property NOT verified with max difference 3.4380286144294594
# overall time: 581.722541809082
# 3/49 | image index 43 ===========================================================================================
# start with optimization
# var 0: -6.907894626880275
# var 1: 2.0715104781081575
# var 2: -2.00721575574026
# var 3: 6.369952606156358
# var 4: -0.8977330280679263
# var 5: 1.0308720589650378
# var 6: -10.480722624323064
# var 7: 3.2105073466095178
# var 8: 3.0313864520563483
# var 9: 6.3427852534280476
# property NOT verified with max difference 0.027167352728310352
# overall time: 515.8767669200897
# 4/49 | image index 44 ===========================================================================================
# start with optimization
# var 0: -5.865768674550754
# var 1: 4.134446315722412
# var 2: 4.276786525167292
# var 3: 9.621440147713281
# var 4: -5.81510203331657
# var 5: -0.4371372908006048
# var 6: -10.959728978319403
# var 7: 5.876665347375885
# var 8: 1.0972947562567796
# var 9: 1.3802907809757752
# property verified with max difference -3.744774800337396
# overall time: 489.16192746162415
# 5/49 | image index 45 ===========================================================================================
# start with optimization
# var 0: -4.00001491160663
# var 1: -5.113842057940403
# var 2: -3.587617349769781
# var 3: 2.65733077971654
# var 4: 1.3748789504590704
# var 5: 3.3819948223415484
# var 6: -10.135402871685791
# var 7: -1.322582313006471
# var 8: 7.395443645607493
# var 9: 9.082328977502023
# property verified with max difference -1.6868853318945298
# overall time: 467.5873055458069
# 6/49 | image index 46 ===========================================================================================
# start with optimization
# var 0: 1.0219442147713496
# var 1: -0.25925376307242853
# var 2: 6.701383328545444
# var 3: 3.96364972489697
# var 4: -10.044062277951536
# var 5: 1.4393054709722906
# var 6: -4.959982759806766
# var 7: -1.3847101878276744
# var 8: 6.476750793993529
# var 9: -1.5915456121349818
# property NOT verified with max difference 0.22463253455191534
# overall time: 403.08920097351074
# 7/49 | image index 47 ===========================================================================================
# start with optimization
# var 0: -2.5026168406325358
# var 1: -1.2444565690457132
# var 2: -4.058376319734666
# var 3: 0.49287946187269505
# var 4: -0.20051110462109278
# var 5: 10.960104602035125
# var 6: -0.24888510490802673
# var 7: -6.646020112202132
# var 8: 5.729968900321451
# var 9: -1.6960380814158498
# property verified with max difference -5.2301357017136745
# overall time: 215.44271230697632
# 8/49 | image index 48 ===========================================================================================
# start with optimization
# var 0: -5.1001921873618965
# var 1: 2.460225820890825
# var 2: -3.6700631704317415
# var 3: 4.186099639921323
# var 4: -2.8029211861700487
# var 5: 6.605002881045438
# var 6: -4.611725703371561
# var 7: -1.498586130531499
# var 8: 3.709031625089831
# var 9: 2.188431260171474
# property NOT verified with max difference 4.416571620873964
# overall time: 233.73379707336426
# 9/49 | image index 49 ===========================================================================================
# start with optimization
# var 0: -1.929752892932644
# var 1: 1.4379522889300027
# var 2: -2.2416843943752127
# var 3: 10.456842648168426
# var 4: -9.216084422201746
# var 5: 9.924875433244358
# var 6: -7.621734962489345
# var 7: -5.242203752262309
# var 8: 4.7896598046264245
# var 9: 1.9175584581653489
# property verified with max difference -0.5319672149240677
# overall time: 167.73766350746155

# %%
print(not_verified_index_snr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(not_verified_index_snr)
#
# NameError: name 'not_verified_index_snr' is not defined

# %%
not_verified_index_snr = [(43, 3), (46, 6), (48, 8)]

# %%
group_size = 20
sample_count = 1000
sampling_method = "per_group_sampling"
net_size = [5, 1]
icnn_factory = ICNNFactory("logical", net_size, always_use_logical_layer=False)
#icnn_factory = ICNNFactory("standard", net_size, adapt_layer_for_init=True)
#icnn_factory = ICNNFactory("approx_max", net_size, maximum_function="SMU", function_parameter=0.3)

dhov_verifier_list = []
not_verified_index_dhov = []
sample_index = 0
round_index = 0
samples_to_verify_dhov = len(not_verified_index_snr)
for touple in not_verified_index_snr:
    sample_index = touple[0]
    round_index = touple[1]
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    #bounds_affine_out_snr, bounds_layer_out_snr = snr_verifier_list[round_index].bounds_affine_out, snr_verifier_list[round_index].bounds_layer_out
    bounds_affine_out_snr, bounds_layer_out_snr = None, None

    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_dhov-1, sample_index))


    overall_time = time.time()
    dhov_verifier = multidhov.MultiDHOV()
    dhov_verifier.start_verification(nn, torch_image, icnn_factory, group_size, eps=eps, icnn_epochs=200, init_affine_bounds=bounds_affine_out_snr, init_layer_bounds=bounds_layer_out_snr,
                                     icnn_batch_size=10000, sample_count=sample_count, sample_new=True, use_over_approximation=True, break_after=None,
                                     sample_over_input_space=False, sample_over_output_space=True, tighten_bounds=True,
                                     use_fixed_neurons_in_grouping=False, sampling_method=sampling_method, layers_as_snr=[], layers_as_milp=[3],
                                     force_inclusion_steps=3, preemptive_stop=True, even_gradient_training=False,
                                     keep_ambient_space=False, data_grad_descent_steps=0, opt_steps_gd=100,
                                     train_outer=False, print_training_loss=False, print_new_bounds=False,
                                     grouping_method="consecutive", group_num_multiplier=5, store_samples=False, print_optimization_steps=False, print_last_loss=False,
                                     should_plot="none", optimizer="SdLBFGS", init_network=True, adapt_lambda="included")


    dhov_verifier_list.append(dhov_verifier)

    dhov_model = dhov_verifier.nn_encoding_model.copy()
    dhov_model.update()
    dhov_out_vars = get_output_vars_dhov(dhov_model, output_size, number_layer)
    add_output_constraints(dhov_model, dhov_verifier.bounds_layer_out, label, dhov_out_vars, sovler_bound=float("inf"))
    successful_ver = optimize_model(dhov_model, dhov_out_vars)
    if not successful_ver:
        not_verified_index_dhov.append(sample_index)
    print("overall time: {}".format(time.time() - overall_time))
    round_index += 1
    sample_index += 1
# Out:
# 3/2 | image index 43 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 159
#     layer progress, group 1 of 5
#         time for sampling for one group: 0.18610119819641113
#         time for training: 12.06511116027832
#         actual verification time 1.2580482959747314
#         time for verification: 1.5271096229553223
#     layer progress, group 2 of 5
#         time for sampling for one group: 0.11100006103515625
#         time for training: 7.317829370498657
#         actual verification time 1.3116767406463623
#         time for verification: 1.5372240543365479
#     layer progress, group 3 of 5
#         time for sampling for one group: 0.09700131416320801
#         time for training: 5.6636528968811035
#         actual verification time 4.196146726608276
#         time for verification: 4.428155899047852
#     layer progress, group 4 of 5
#         time for sampling for one group: 0.08399438858032227
#         time for training: 4.618877649307251
#         actual verification time 5.24802041053772
#         time for verification: 5.446030616760254
#     layer progress, group 5 of 5
#         time for sampling for one group: 0.07799911499023438
#         time for training: 4.297330379486084
#         actual verification time 1.0047307014465332
#         time for verification: 1.2068431377410889
#
# approximation of layer: 1
#     time for icnn_bound calculation: 71.1387586593628
#     number of fixed neurons for current layer: 172
#     layer progress, group 1 of 5
#         time for sampling for one group: 61.700891733169556
#         time for training: 15.891502141952515
#         actual verification time 22.325515031814575
#         time for verification: 22.512521982192993
#     layer progress, group 2 of 5
#         time for sampling for one group: 75.79087734222412
#         time for training: 9.004592180252075
#         actual verification time 31.031680583953857
#         time for verification: 31.245677709579468
#     layer progress, group 3 of 5
#         time for sampling for one group: 53.116750955581665
#         time for training: 7.83086633682251
#         actual verification time 28.235339403152466
#         time for verification: 28.47434091567993
#     layer progress, group 4 of 5
#         time for sampling for one group: 50.383275508880615
#         time for training: 4.989297389984131
#         actual verification time 21.857871055603027
#         time for verification: 22.0425546169281
#     layer progress, group 5 of 5
#         time for sampling for one group: 70.84582114219666
#         time for training: 9.244302749633789
#         actual verification time 1.946667194366455
#         time for verification: 2.032665252685547
#
# approximation of layer: 2
#     time for icnn_bound calculation: 197.54521560668945
#     number of fixed neurons for current layer: 178
#     layer progress, group 1 of 4
#         time for sampling for one group: 222.48842906951904
#         time for training: 6.116932392120361
#         actual verification time 18.182464599609375
#         time for verification: 18.438469409942627
#     layer progress, group 2 of 4
#         time for sampling for one group: 318.2544479370117
#         time for training: 29.0612154006958
#         actual verification time 48.13354277610779
#         time for verification: 48.404597759246826
#     layer progress, group 3 of 4
#         time for sampling for one group: 226.07779026031494
#         time for training: 5.426492214202881
#         actual verification time 111.4607458114624
#         time for verification: 111.70175957679749
#     layer progress, group 4 of 4
#         time for sampling for one group: 214.4615182876587
#         time for training: 6.2034995555877686
#         actual verification time 91.17569065093994
#         time for verification: 91.3756992816925
#
# approximation of layer: 3
#     time for icnn_bound calculation: 732.7411332130432
#     number of fixed neurons for current layer: 178
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.007013082504272461
# done...
# var 0: -6.5377586647307995
# var 1: 0.40667894858439624
# var 2: -3.9640735414814428
# var 3: 3.0654240605999323
# var 4: 0.8044490986178143
# var 5: 1.570480817593582
# var 6: -9.096901820062307
# var 7: 0.16740814814180904
# var 8: 6.604051685005524
# var 9: 7.917665071125085
# property verified with max difference -1.3136133861195605
# overall time: 2877.4686830043793
# 6/2 | image index 46 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 162
#     layer progress, group 1 of 5
#         time for sampling for one group: 0.19399785995483398
#         time for training: 7.9256486892700195
#         actual verification time 2.8592724800109863
#         time for verification: 3.138295888900757
#     layer progress, group 2 of 5
#         time for sampling for one group: 0.2930011749267578
#         time for training: 13.827930688858032
#         actual verification time 2.112711191177368
#         time for verification: 2.4147233963012695
#     layer progress, group 3 of 5
#         time for sampling for one group: 0.1289961338043213
#         time for training: 5.779727458953857
#         actual verification time 5.121564865112305
#         time for verification: 5.325579881668091
#     layer progress, group 4 of 5
#         time for sampling for one group: 0.10099601745605469
#         time for training: 5.000805139541626
#         actual verification time 1.227273941040039
#         time for verification: 1.437274694442749
#     layer progress, group 5 of 5
#         time for sampling for one group: 0.06699919700622559
#         time for training: 7.1500084400177
#         actual verification time 0.4508979320526123
#         time for verification: 0.612905740737915
#
# approximation of layer: 1
#     time for icnn_bound calculation: 48.91879177093506
#     number of fixed neurons for current layer: 177
#     layer progress, group 1 of 4
#         time for sampling for one group: 35.51544713973999
#         time for training: 11.537323236465454
#         actual verification time 36.26827049255371
#         time for verification: 36.5852427482605
#     layer progress, group 2 of 4
#         time for sampling for one group: 39.62621831893921
#         time for training: 5.3029046058654785
#         actual verification time 60.36968755722046
#         time for verification: 60.632683753967285
#     layer progress, group 3 of 4
#         time for sampling for one group: 69.42000555992126
#         time for training: 10.280221223831177
#         actual verification time 40.930676221847534
#         time for verification: 41.2885262966156
#     layer progress, group 4 of 4
#         time for sampling for one group: 37.00957250595093
#         time for training: 4.817760705947876
#         actual verification time 12.655199766159058
#         time for verification: 12.848212003707886
#
# approximation of layer: 2
#     time for icnn_bound calculation: 251.01562547683716
#     number of fixed neurons for current layer: 203
#     layer progress, group 1 of 3
#         time for sampling for one group: 261.4192428588867
#         time for training: 8.911295890808105
#         actual verification time 47.91731667518616
#         time for verification: 48.17132568359375
#     layer progress, group 2 of 3
#         time for sampling for one group: 192.22741031646729
#         time for training: 6.727061033248901
#         actual verification time 77.5229983329773
#         time for verification: 77.73500728607178
#     layer progress, group 3 of 3
#         time for sampling for one group: 224.57230067253113
#         time for training: 6.6089513301849365
#         actual verification time 21.751163244247437
#         time for verification: 21.913697242736816
#
# approximation of layer: 3
#     time for icnn_bound calculation: 730.7716341018677
#     number of fixed neurons for current layer: 201
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.01599597930908203
# done...
# var 0: 1.0843425335362271
# var 1: -0.2663861020168845
# var 2: 6.583290225733312
# var 3: 4.016710882607625
# var 4: -10.201264026580569
# var 5: 1.4186465858948676
# var 6: -4.852959611574427
# var 7: -1.7629431726595115
# var 8: 7.057364611720205
# var 9: -1.5997962341232395
# property verified with max difference -0.4740743859868932
# overall time: 2348.674960374832
# 8/2 | image index 48 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 177
#     layer progress, group 1 of 4
#         time for sampling for one group: 0.16800284385681152
#         time for training: 9.86499547958374
#         actual verification time 1.560349464416504
#         time for verification: 1.798354148864746
#     layer progress, group 2 of 4
#         time for sampling for one group: 0.10500144958496094
#         time for training: 7.653690814971924
#         actual verification time 1.3583269119262695
#         time for verification: 1.6833229064941406
#     layer progress, group 3 of 4
#         time for sampling for one group: 0.20400786399841309
#         time for training: 11.948529958724976
#         actual verification time 1.7355434894561768
#         time for verification: 2.027061700820923
#     layer progress, group 4 of 4
#         time for sampling for one group: 0.1460111141204834
#         time for training: 7.5522942543029785
#         actual verification time 2.7256176471710205
#         time for verification: 2.967623472213745
#
# approximation of layer: 1
#     time for icnn_bound calculation: 45.8572518825531
#     number of fixed neurons for current layer: 190
#     layer progress, group 1 of 4
#         time for sampling for one group: 44.37262296676636
#         time for training: 5.311725616455078
#         actual verification time 18.07970666885376
#         time for verification: 18.274271965026855
#     layer progress, group 2 of 4
#         time for sampling for one group: 32.11635994911194
#         time for training: 5.82314920425415
#         actual verification time 31.90345597267151
#         time for verification: 32.16829776763916
#     layer progress, group 3 of 4
#         time for sampling for one group: 39.03872895240784
#         time for training: 8.764143466949463
#         actual verification time 24.674663305282593
#         time for verification: 24.951674461364746
#     layer progress, group 4 of 4
#         time for sampling for one group: 31.440496921539307
#         time for training: 10.661143064498901
#         actual verification time 6.9853715896606445
#         time for verification: 7.097366571426392
#
# approximation of layer: 2
#     time for icnn_bound calculation: 143.30496644973755
#     number of fixed neurons for current layer: 196
#     layer progress, group 1 of 3
#         time for sampling for one group: 158.0105402469635
#         time for training: 12.459312915802002
#         actual verification time 160.7504425048828
#         time for verification: 161.04445266723633
#     layer progress, group 2 of 3
#         time for sampling for one group: 220.0847132205963
#         time for training: 8.464507818222046
#         actual verification time 68.60840368270874
#         time for verification: 68.812420129776
#     layer progress, group 3 of 3
#         time for sampling for one group: 179.4803705215454
#         time for training: 18.96957039833069
#         actual verification time 30.129895210266113
#         time for verification: 30.33190608024597
#
# approximation of layer: 3
#     time for icnn_bound calculation: 503.12633085250854
#     number of fixed neurons for current layer: 181
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.0070037841796875
# done...
# var 0: -5.209889258656172
# var 1: 2.4566863159857566
# var 2: -3.891671804645159
# var 3: 4.19578862357532
# var 4: -2.817329098227627
# var 5: 6.310641022937588
# var 6: -4.889513925202456
# var 7: -1.5819645684613457
# var 8: 3.9968141119097194
# var 9: 2.72025432288474
# property NOT verified with max difference 3.5903867000528487
# overall time: 1894.6535685062408
