# %%
import torch
import time
from script.NeuralNets.Networks import SequentialNN
from script.settings import device, data_type
import script.DHOV.MultiDHOV as multidhov
from script.Verification.Verifier import SingleNeuronVerifier, MILPVerifier
import gurobipy as grp
from torchvision.datasets import MNIST
from torchvision.transforms import Compose, ToTensor, Normalize
from script.NeuralNets.ICNNFactory import ICNNFactory
import matplotlib.pyplot as plt
from script import eval

# %%
def add_output_constraints(model, nn_layer_out_bounds, label, output_vars, sovler_bound=1e-3):
    out_lb = nn_layer_out_bounds[-1][0]
    out_ub = nn_layer_out_bounds[-1][1]
    difference_lb = out_lb - out_ub[label]
    difference_ub = out_ub - out_lb[label]
    difference_lb = difference_lb.tolist()
    difference_ub = difference_ub.tolist()
    difference_lb.pop(label)
    difference_ub.pop(label)
    min_diff = min(difference_lb)
    max_diff = max(difference_ub)

    difference = model.addVars(9, lb=difference_lb, ub=difference_ub, name="diff_var")
    model.addConstrs((difference[i] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(0, label)), name="diff_const0")
    model.addConstrs((difference[i - 1] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(label + 1, 10)), name="diff_const1")

    max_var = model.addVar(lb=min_diff, ub=max_diff, name="max_var")
    model.addConstr(max_var == grp.max_(difference))

    if sovler_bound != None:
        model.setParam("BestObjStop", sovler_bound)

    model.update()
    model.setObjective(max_var, grp.GRB.MAXIMIZE)

# %%
def get_output_vars_snv_milp(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("affine_var{}[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def get_output_vars_dhov(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("output_layer_[{}]_[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def optimize_model(model, output_vars):
    start = time.time()
    model.update()
    model.optimize()
    if model.Status == grp.GRB.OPTIMAL or model.Status == grp.GRB.USER_OBJ_LIMIT:
        for i, var in enumerate(output_vars.tolist()):
            print("var {}: {}".format(i, var.getAttr("x")))
        max_var = model.getVarByName("max_var").getAttr("x")
        if max_var < 0:
            print("property verified with max difference {}".format(max_var))
            return True
        else:
             print("property NOT verified with max difference {}".format(max_var))
             return False

    elif model.Status == grp.GRB.INFEASIBLE:
        print("model infeasible")

        model.computeIIS()
        print("constraint")
        all_constr = model.getConstrs()

        for const in all_constr:
            if const.IISConstr:
                print("{}".format(const))

        print("lower bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISLB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

        print("upper bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISUB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

    print("time to optimize: {}".format(time.time() - start))
    return False

# %%
transform = Compose([ToTensor(),  Normalize(0.5, 0.5)])
training_data = MNIST(root="../../mnist", train=True, download=True, transform=transform)

nn = SequentialNN([28 * 28 * 1, 256, 256, 256, 256, 10])
nn.load_state_dict(torch.load("../../mnist_fc 4x256.pth", map_location=torch.device('cpu')), strict=False)
parameter_list = list(nn.parameters())
output_size = 10
number_layer = (len(parameter_list) - 2) // 2

eps = 0.026
samples_to_verify_count = 30

# %% [markdown]
# DHOV

# %% [markdown]
# SNR

# %%
snr_verifier_list = []
not_verified_index_snr = []
sample_index = 20
round_index = 0
while sample_index < samples_to_verify_count:
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    simple_bounds_affine_out, simple_bounds_layer_out = nn.calculate_box_bounds([input_flattened.add(-eps), input_flattened.add(eps)])

    if not torch.argmax(nn(torch_image)).item() == label:
        sample_index += 1
        continue
    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_count-1, sample_index))

    overall_time = time.time()
    snv_verifier = SingleNeuronVerifier(nn, torch_image, eps, print_log=False, print_new_bounds=False, optimize_bounds=True)
    snv_verifier.generate_constraints_for_net()
    snr_verifier_list.append(snv_verifier)
    snv_model = snv_verifier.model.copy()
    snv_model.update()
    snv_out_vars = get_output_vars_snv_milp(snv_model, output_size, number_layer * 2)
    add_output_constraints(snv_model, simple_bounds_layer_out, label, snv_out_vars, sovler_bound=None)

    print("start with optimization")
    successful_ver = optimize_model(snv_model, snv_out_vars)
    if not successful_ver:
        not_verified_index_snr.append((sample_index, round_index))
    print("overall time: {}".format(time.time() - overall_time))

    round_index += 1
    sample_index += 1
# Out:
# 0/29 | image index 20 ===========================================================================================
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-11-12
# start with optimization
# var 0: -3.3422912182222335
# var 1: -3.8372910492998598
# var 2: 5.218327223920892
# var 3: 0.7716945370021202
# var 4: 6.311766729624947
# var 5: -2.939887555041838
# var 6: 0.10786441181747808
# var 7: -1.6601142560515578
# var 8: -0.31954884653458837
# var 9: -0.9088288582146253
# property verified with max difference -1.0934395057040547
# overall time: 241.3984661102295
# 1/29 | image index 21 ===========================================================================================
# start with optimization
# var 0: 7.307247523473394
# var 1: -3.5489308896198386
# var 2: 3.8801290884353064
# var 3: 1.0777488019888422
# var 4: -6.883174272917864
# var 5: 1.268162052040016
# var 6: -1.0249669495030274
# var 7: 0.2762249789300535
# var 8: -0.4737750996875141
# var 9: -1.337371826958889
# property verified with max difference -3.4271184350380874
# overall time: 434.7088952064514
# 2/29 | image index 22 ===========================================================================================
# start with optimization
# var 0: -5.910458381894925
# var 1: -1.036071721491017
# var 2: -1.3169245868343067
# var 3: -1.8469676076607113
# var 4: 6.5025989470188605
# var 5: -0.5659232951058382
# var 6: -3.691116113833367
# var 7: 1.2486747824061992
# var 8: 2.1554590705367374
# var 9: 3.959648402428119
# property NOT verified with max difference 2.542950544590742
# overall time: 590.2446732521057
# 3/29 | image index 23 ===========================================================================================
# start with optimization
# var 0: -6.336296153206244
# var 1: 6.596029104506644
# var 2: 1.2781904442141743
# var 3: 0.6324598121204081
# var 4: -0.6891674686260023
# var 5: -1.226986962031412
# var 6: -2.6423128469195634
# var 7: 0.9991936513870892
# var 8: 4.726003387590861
# var 9: -1.3690268286955911
# property verified with max difference -1.8700257169157828
# overall time: 484.88804721832275
# 4/29 | image index 25 ===========================================================================================
# start with optimization
# var 0: -1.1911983334571694
# var 1: 3.696014224449174
# var 2: 10.552146700036063
# var 3: 10.628281215586423
# var 4: -11.876277338223627
# var 5: -0.4592007973448169
# var 6: -7.497351074650863
# var 7: -1.1693919318586428
# var 8: 5.660478473773565
# var 9: -4.416768246007123
# property NOT verified with max difference 0.07613451555035944
# overall time: 231.8166148662567
# 5/29 | image index 26 ===========================================================================================
# start with optimization
# var 0: -6.1590698492132425
# var 1: -0.8359308054170498
# var 2: -3.0474472358452296
# var 3: 1.8982296561987937
# var 4: 3.8437696399135852
# var 5: 0.7583473537184133
# var 6: -6.599715119581356
# var 7: 1.571822672876035
# var 8: 2.2015209671458713
# var 9: 6.353690831869724
# property NOT verified with max difference 2.5099211919561384
# overall time: 659.2900454998016
# 6/29 | image index 27 ===========================================================================================
# start with optimization
# var 0: -4.624650305833033
# var 1: 2.8031472268562396
# var 2: 2.4547250289858074
# var 3: 16.548987521945833
# var 4: -9.720349705053454
# var 5: 2.4991146784709333
# var 6: -14.76729809013401
# var 7: -0.13930102194511562
# var 8: 5.838271071111615
# var 9: 3.3926364346036078
# property verified with max difference -10.710716450834218
# overall time: 203.18103504180908
# 7/29 | image index 28 ===========================================================================================
# start with optimization
# var 0: 2.210049477507914
# var 1: -0.9572625930246463
# var 2: 10.297101134033584
# var 3: 3.5189680043833125
# var 4: -8.987930693856612
# var 5: -4.4057963672750535
# var 6: -8.855978060499945
# var 7: 8.798048667707922
# var 8: 2.1767041113289807
# var 9: -1.7363408472080284
# property verified with max difference -1.4990524663256615
# overall time: 229.40235900878906
# 8/29 | image index 29 ===========================================================================================
# start with optimization
# var 0: -2.4552621153872893
# var 1: 1.6146197553633739
# var 2: 1.1385836495423094
# var 3: -1.9274906881649825
# var 4: -0.17463085790487565
# var 5: -0.6566769154563294
# var 6: 0.07923105505483807
# var 7: 0.3368043862101091
# var 8: 3.6625742935588095
# var 9: -1.2863209781370015
# property NOT verified with max difference 3.3257699073487004
# overall time: 381.4338812828064

# %%
print(not_verified_index_snr)
# Out:
# [(22, 2), (25, 4), (26, 5), (29, 8)]

# %%
not_verified_index_snr = [(22, 2), (25, 4), (26, 5)]

# %%
group_size = 20
sample_count = 1000
sampling_method = "per_group_sampling"
net_size = [5, 1]
icnn_factory = ICNNFactory("logical", net_size, always_use_logical_layer=False)
#icnn_factory = ICNNFactory("standard", net_size, adapt_layer_for_init=True)
#icnn_factory = ICNNFactory("approx_max", net_size, maximum_function="SMU", function_parameter=0.3)

dhov_verifier_list = []
not_verified_index_dhov = []
sample_index = 0
round_index = 0
samples_to_verify_dhov = len(not_verified_index_snr)
for touple in not_verified_index_snr:
    sample_index = touple[0]
    round_index = touple[1]
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    #bounds_affine_out_snr, bounds_layer_out_snr = snr_verifier_list[round_index].bounds_affine_out, snr_verifier_list[round_index].bounds_layer_out
    bounds_affine_out_snr, bounds_layer_out_snr = None, None

    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_dhov-1, sample_index))


    overall_time = time.time()
    dhov_verifier = multidhov.MultiDHOV()
    dhov_verifier.start_verification(nn, torch_image, icnn_factory, group_size, eps=eps, icnn_epochs=200, init_affine_bounds=bounds_affine_out_snr, init_layer_bounds=bounds_layer_out_snr,
                                     icnn_batch_size=10000, sample_count=sample_count, sample_new=True, use_over_approximation=True, break_after=None,
                                     sample_over_input_space=False, sample_over_output_space=True, tighten_bounds=True,
                                     use_fixed_neurons_in_grouping=False, sampling_method=sampling_method, layers_as_snr=[], layers_as_milp=[3],
                                     force_inclusion_steps=3, preemptive_stop=True, even_gradient_training=False,
                                     keep_ambient_space=False, data_grad_descent_steps=0, opt_steps_gd=100,
                                     train_outer=False, print_training_loss=False, print_new_bounds=False,
                                     grouping_method="consecutive", group_num_multiplier=5, store_samples=False, print_optimization_steps=False, print_last_loss=False,
                                     should_plot="none", optimizer="SdLBFGS", init_network=True, adapt_lambda="included")


    dhov_verifier_list.append(dhov_verifier)

    dhov_model = dhov_verifier.nn_encoding_model.copy()
    dhov_model.update()
    dhov_out_vars = get_output_vars_dhov(dhov_model, output_size, number_layer)
    add_output_constraints(dhov_model, dhov_verifier.bounds_layer_out, label, dhov_out_vars, sovler_bound=float("inf"))
    successful_ver = optimize_model(dhov_model, dhov_out_vars)
    if not successful_ver:
        not_verified_index_dhov.append(sample_index)
    print("overall time: {}".format(time.time() - overall_time))
    round_index += 1
    sample_index += 1
# Out:
# 2/2 | image index 22 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 159
#     layer progress, group 1 of 5
#         time for sampling for one group: 0.10199904441833496
#         time for training: 5.424808025360107
#         actual verification time 2.0951883792877197
#         time for verification: 2.3331897258758545
#     layer progress, group 2 of 5
#         time for sampling for one group: 0.12199878692626953
#         time for training: 9.766342639923096
#         actual verification time 1.754680871963501
#         time for verification: 1.9876806735992432
#     layer progress, group 3 of 5
#         time for sampling for one group: 0.1430809497833252
#         time for training: 20.338887453079224
#         actual verification time 0.9025168418884277
#         time for verification: 1.138516902923584
#     layer progress, group 4 of 5
#         time for sampling for one group: 0.11699962615966797
#         time for training: 11.672247886657715
#         actual verification time 2.482145309448242
#         time for verification: 2.699143409729004
#     layer progress, group 5 of 5
#         time for sampling for one group: 0.17010712623596191
#         time for training: 10.990015983581543
#         actual verification time 1.158154010772705
#         time for verification: 1.3671586513519287
#
# approximation of layer: 1
#     time for icnn_bound calculation: 53.521661043167114
#     number of fixed neurons for current layer: 153
#     layer progress, group 1 of 6
#         time for sampling for one group: 63.083603382110596
#         time for training: 7.152640342712402
#         actual verification time 22.639745712280273
#         time for verification: 22.964744091033936
#     layer progress, group 2 of 6
#         time for sampling for one group: 63.02805233001709
#         time for training: 8.062206983566284
#         actual verification time 35.44586634635925
#         time for verification: 35.75248599052429
#     layer progress, group 3 of 6
#         time for sampling for one group: 69.17400693893433
#         time for training: 10.568745374679565
#         actual verification time 18.39794635772705
#         time for verification: 18.62898826599121
#     layer progress, group 4 of 6
#         time for sampling for one group: 65.76365518569946
#         time for training: 9.166943073272705
#         actual verification time 21.965611696243286
#         time for verification: 22.26372265815735
#     layer progress, group 5 of 6
#         time for sampling for one group: 46.15583610534668
#         time for training: 8.009809017181396
#         actual verification time 56.37119269371033
#         time for verification: 56.593207120895386
#     layer progress, group 6 of 6
#         time for sampling for one group: 39.41767930984497
#         time for training: 5.127974510192871
#         actual verification time 0.622002363204956
#         time for verification: 0.6990072727203369
#
# approximation of layer: 2
#     time for icnn_bound calculation: 264.20308566093445
#     number of fixed neurons for current layer: 171
#     layer progress, group 1 of 5
#         time for sampling for one group: 323.9511384963989
#         time for training: 9.123457193374634
#         actual verification time 29.48381495475769
#         time for verification: 29.7298104763031
#     layer progress, group 2 of 5
#         time for sampling for one group: 324.88925862312317
#         time for training: 7.550254821777344
#         actual verification time 53.78639078140259
#         time for verification: 53.99339580535889
#     layer progress, group 3 of 5
#         time for sampling for one group: 282.18415689468384
#         time for training: 8.43201732635498
#         actual verification time 31.202945709228516
#         time for verification: 31.42096734046936
#     layer progress, group 4 of 5
#         time for sampling for one group: 279.5349931716919
#         time for training: 6.31475043296814
#         actual verification time 81.21091985702515
#         time for verification: 81.4499340057373
#     layer progress, group 5 of 5
#         time for sampling for one group: 304.50288915634155
#         time for training: 35.48763036727905
#         actual verification time 9.63740611076355
#         time for verification: 9.793413639068604
#
# approximation of layer: 3
#     time for icnn_bound calculation: 1022.3075349330902
#     number of fixed neurons for current layer: 164
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.01101541519165039
# done...
# var 0: -6.246977967193336
# var 1: -1.3665766640050716
# var 2: -1.939062470917838
# var 3: -1.8186048760541365
# var 4: 6.709607983411204
# var 5: -0.5278978684533326
# var 6: -4.0856216296863845
# var 7: 0.9472845916554276
# var 8: 2.392048651272395
# var 9: 5.203390601648605
# property NOT verified with max difference 1.5062173817625988
# overall time: 3859.7085797786713
# 4/2 | image index 25 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 183
#     layer progress, group 1 of 4
#         time for sampling for one group: 0.13300132751464844
#         time for training: 10.051751375198364
#         actual verification time 1.6400775909423828
#         time for verification: 1.8590831756591797
#     layer progress, group 2 of 4
#         time for sampling for one group: 0.10199689865112305
#         time for training: 4.812116384506226
#         actual verification time 0.8729922771453857
#         time for verification: 1.0869989395141602
#     layer progress, group 3 of 4
#         time for sampling for one group: 0.09600043296813965
#         time for training: 5.154010534286499
#         actual verification time 1.1314585208892822
#         time for verification: 1.332465648651123
#     layer progress, group 4 of 4
#         time for sampling for one group: 0.06699991226196289
#         time for training: 7.234399080276489
#         actual verification time 0.38147568702697754
#         time for verification: 0.5504848957061768
#
# approximation of layer: 1
#     time for icnn_bound calculation: 41.25159573554993
#     number of fixed neurons for current layer: 211
#     layer progress, group 1 of 3
#         time for sampling for one group: 46.29286599159241
#         time for training: 10.263007879257202
#         actual verification time 9.6717529296875
#         time for verification: 9.86876392364502
#     layer progress, group 2 of 3
#         time for sampling for one group: 31.675840139389038
#         time for training: 11.470794200897217
#         actual verification time 29.626049995422363
#         time for verification: 29.95305609703064
#     layer progress, group 3 of 3
#         time for sampling for one group: 29.017757892608643
#         time for training: 13.062709093093872
#         actual verification time 1.949646234512329
#         time for verification: 2.0596511363983154
#
# approximation of layer: 2
#     time for icnn_bound calculation: 136.66224098205566
#     number of fixed neurons for current layer: 220
#     layer progress, group 1 of 2
#         time for sampling for one group: 77.5592348575592
#         time for training: 11.382351398468018
#         actual verification time 84.26579689979553
#         time for verification: 84.61693358421326
#     layer progress, group 2 of 2
#         time for sampling for one group: 87.55480003356934
#         time for training: 7.384024381637573
#         actual verification time 67.51989769935608
#         time for verification: 67.7209095954895
#
# approximation of layer: 3
#     time for icnn_bound calculation: 302.4228618144989
#     number of fixed neurons for current layer: 233
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.008999824523925781
# done...
# var 0: -1.1392270751284492
# var 1: 3.7031709098400123
# var 2: 10.719838670328018
# var 3: 10.524660970434581
# var 4: -11.936312523307414
# var 5: -0.48710135504934193
# var 6: -7.420111688080551
# var 7: -1.151499343958415
# var 8: 5.646543455500616
# var 9: -4.542026131803242
# property verified with max difference -0.19517769989343584
# overall time: 1053.6550245285034
# 5/2 | image index 26 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 143
#     layer progress, group 1 of 6
#         time for sampling for one group: 0.15900063514709473
#         time for training: 13.72624397277832
#         actual verification time 1.6665441989898682
#         time for verification: 1.8545513153076172
#     layer progress, group 2 of 6
#         time for sampling for one group: 0.07199716567993164
#         time for training: 5.667720317840576
#         actual verification time 1.0401649475097656
#         time for verification: 1.2391667366027832
#     layer progress, group 3 of 6
#         time for sampling for one group: 0.09599804878234863
#         time for training: 5.2805399894714355
#         actual verification time 2.553649425506592
#         time for verification: 2.7496492862701416
#     layer progress, group 4 of 6
#         time for sampling for one group: 0.10399556159973145
#         time for training: 5.069379806518555
#         actual verification time 9.293543338775635
#         time for verification: 9.504558086395264
#     layer progress, group 5 of 6
#         time for sampling for one group: 0.10299563407897949
#         time for training: 6.7660486698150635
#         actual verification time 2.514028787612915
#         time for verification: 2.791553258895874
#     layer progress, group 6 of 6
#         time for sampling for one group: 0.09200024604797363
#         time for training: 9.168311834335327
#         actual verification time 1.2157235145568848
#         time for verification: 1.4467086791992188
#
# approximation of layer: 1
#     time for icnn_bound calculation: 79.68193912506104
#     number of fixed neurons for current layer: 164
#     layer progress, group 1 of 5
#         time for sampling for one group: 97.01428604125977
#         time for training: 13.827061891555786
#         actual verification time 62.779670000076294
#         time for verification: 63.04367136955261
#     layer progress, group 2 of 5
#         time for sampling for one group: 75.36009693145752
#         time for training: 13.246373653411865
#         actual verification time 13.900928735733032
#         time for verification: 14.30009388923645
#     layer progress, group 3 of 5
#         time for sampling for one group: 53.969714641571045
#         time for training: 13.192810297012329
#         actual verification time 11.115735292434692
#         time for verification: 11.318853378295898
#     layer progress, group 4 of 5
#         time for sampling for one group: 51.45729899406433
#         time for training: 6.967251777648926
#         actual verification time 18.865147590637207
#         time for verification: 19.097137689590454
#     layer progress, group 5 of 5
#         time for sampling for one group: 65.71058654785156
#         time for training: 11.308913230895996
#         actual verification time 15.006353378295898
#         time for verification: 15.189353704452515
#
# approximation of layer: 2
#     time for icnn_bound calculation: 277.358993768692
#     number of fixed neurons for current layer: 174
#     layer progress, group 1 of 5
#         time for sampling for one group: 455.2506592273712
#         time for training: 14.647306442260742
#         actual verification time 18.186725616455078
#         time for verification: 18.435719966888428
#     layer progress, group 2 of 5
#         time for sampling for one group: 341.7612347602844
#         time for training: 7.029638051986694
#         actual verification time 60.76025104522705
#         time for verification: 60.967267990112305
#     layer progress, group 3 of 5
#         time for sampling for one group: 279.7140038013458
#         time for training: 13.4871346950531
#         actual verification time 23.124547004699707
#         time for verification: 23.325562238693237
#     layer progress, group 4 of 5
#         time for sampling for one group: 277.6095771789551
#         time for training: 14.089367628097534
#         actual verification time 50.578659534454346
#         time for verification: 50.836663246154785
#     layer progress, group 5 of 5
#         time for sampling for one group: 256.69816279411316
#         time for training: 13.247909307479858
#         actual verification time 1.924037218093872
#         time for verification: 1.9650347232818604
#
# approximation of layer: 3
#     time for icnn_bound calculation: 486.94173192977905
#     number of fixed neurons for current layer: 161
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.004999399185180664
# done...
# var 0: -6.752473676767932
# var 1: -0.8497399330968713
# var 2: -3.3101372546439647
# var 3: 1.1138301379435065
# var 4: 5.404095119270701
# var 5: 0.13327835304982827
# var 6: -6.499783306741599
# var 7: 1.9376220468453296
# var 8: 2.4801156296865554
# var 9: 6.316942710409365
# property NOT verified with max difference 0.9128475911386646
# overall time: 3323.8908772468567
