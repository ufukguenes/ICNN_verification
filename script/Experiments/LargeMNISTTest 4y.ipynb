# %%
import torch
import time
from script.NeuralNets.Networks import SequentialNN
from script.settings import device, data_type
import script.DHOV.MultiDHOV as multidhov
from script.Verification.Verifier import SingleNeuronVerifier, MILPVerifier
import gurobipy as grp
from torchvision.datasets import MNIST
from torchvision.transforms import Compose, ToTensor, Normalize
from script.NeuralNets.ICNNFactory import ICNNFactory
import matplotlib.pyplot as plt
from script import eval

# %%
def add_output_constraints(model, nn_layer_out_bounds, label, output_vars, sovler_bound=1e-3):
    out_lb = nn_layer_out_bounds[-1][0]
    out_ub = nn_layer_out_bounds[-1][1]
    difference_lb = out_lb - out_ub[label]
    difference_ub = out_ub - out_lb[label]
    difference_lb = difference_lb.tolist()
    difference_ub = difference_ub.tolist()
    difference_lb.pop(label)
    difference_ub.pop(label)
    min_diff = min(difference_lb)
    max_diff = max(difference_ub)

    difference = model.addVars(9, lb=difference_lb, ub=difference_ub, name="diff_var")
    model.addConstrs((difference[i] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(0, label)), name="diff_const0")
    model.addConstrs((difference[i - 1] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(label + 1, 10)), name="diff_const1")

    max_var = model.addVar(lb=min_diff, ub=max_diff, name="max_var")
    model.addConstr(max_var == grp.max_(difference))

    if sovler_bound != None:
        model.setParam("BestObjStop", sovler_bound)

    model.update()
    model.setObjective(max_var, grp.GRB.MAXIMIZE)

# %%
def get_output_vars_snv_milp(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("affine_var{}[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def get_output_vars_dhov(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("output_layer_[{}]_[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def optimize_model(model, output_vars):
    start = time.time()
    model.update()
    model.optimize()
    if model.Status == grp.GRB.OPTIMAL or model.Status == grp.GRB.USER_OBJ_LIMIT:
        for i, var in enumerate(output_vars.tolist()):
            print("var {}: {}".format(i, var.getAttr("x")))
        max_var = model.getVarByName("max_var").getAttr("x")
        if max_var < 0:
            print("property verified with max difference {}".format(max_var))
            return True
        else:
             print("property NOT verified with max difference {}".format(max_var))
             return False

    elif model.Status == grp.GRB.INFEASIBLE:
        print("model infeasible")

        model.computeIIS()
        print("constraint")
        all_constr = model.getConstrs()

        for const in all_constr:
            if const.IISConstr:
                print("{}".format(const))

        print("lower bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISLB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

        print("upper bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISUB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

    print("time to optimize: {}".format(time.time() - start))
    return False

# %%
transform = Compose([ToTensor(),  Normalize(0.5, 0.5)])
training_data = MNIST(root="../../mnist", train=True, download=True, transform=transform)

nn = SequentialNN([28 * 28 * 1, 256, 256, 256, 256, 10])
nn.load_state_dict(torch.load("../../mnist_fc 4x256.pth", map_location=torch.device('cpu')), strict=False)
parameter_list = list(nn.parameters())
output_size = 10
number_layer = (len(parameter_list) - 2) // 2

eps = 0.026
samples_to_verify_count = 40

# %% [markdown]
# DHOV

# %% [markdown]
# SNR

# %%
snr_verifier_list = []
not_verified_index_snr = []
sample_index = 30
round_index = 0
while sample_index < samples_to_verify_count:
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    simple_bounds_affine_out, simple_bounds_layer_out = nn.calculate_box_bounds([input_flattened.add(-eps), input_flattened.add(eps)])

    if not torch.argmax(nn(torch_image)).item() == label:
        sample_index += 1
        continue
    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_count-1, sample_index))

    overall_time = time.time()
    snv_verifier = SingleNeuronVerifier(nn, torch_image, eps, print_log=False, print_new_bounds=False, optimize_bounds=True)
    snv_verifier.generate_constraints_for_net()
    snr_verifier_list.append(snv_verifier)
    snv_model = snv_verifier.model.copy()
    snv_model.update()
    snv_out_vars = get_output_vars_snv_milp(snv_model, output_size, number_layer * 2)
    add_output_constraints(snv_model, simple_bounds_layer_out, label, snv_out_vars, sovler_bound=None)

    print("start with optimization")
    successful_ver = optimize_model(snv_model, snv_out_vars)
    if not successful_ver:
        not_verified_index_snr.append((sample_index, round_index))
    print("overall time: {}".format(time.time() - overall_time))

    round_index += 1
    sample_index += 1
# Out:
# 0/39 | image index 30 ===========================================================================================
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-11-12
# start with optimization
# var 0: -6.972480675906049
# var 1: 7.306061892872637
# var 2: 3.907160952953686
# var 3: 6.0117450917012745
# var 4: -1.625096910798704
# var 5: -2.753038426940109
# var 6: -3.4766305485337687
# var 7: 2.9123912854063816
# var 8: 0.21280069617866193
# var 9: -2.4988355464835186
# property NOT verified with max difference 1.2943168011713624
# overall time: 425.47240710258484
# 1/39 | image index 31 ===========================================================================================
# start with optimization
# var 0: -2.8706501214394624
# var 1: 2.788838549081971
# var 2: 1.8455006994195404
# var 3: 6.045095716086234
# var 4: -6.640827471989136
# var 5: -0.15199508647287097
# var 6: -7.536018764154727
# var 7: -1.751363237052253
# var 8: 8.568327084656607
# var 9: 1.7800781238031806
# property verified with max difference -2.5232313685703733
# overall time: 308.59911608695984
# 2/39 | image index 32 ===========================================================================================
# start with optimization
# var 0: 0.18287729585498447
# var 1: -0.5561033932801296
# var 2: 5.465182129180301
# var 3: -1.604246386657885
# var 4: -0.3469093544058621
# var 5: 0.33948528560208224
# var 6: 4.526223887771612
# var 7: 0.916209489691211
# var 8: -4.183266511836821
# var 9: -4.507683880763357
# property NOT verified with max difference 0.9389582414086887
# overall time: 608.9477431774139
# 3/39 | image index 33 ===========================================================================================
# start with optimization
# var 0: -4.885027698505099
# var 1: 0.9971161925206458
# var 2: -0.6276276346108345
# var 3: 3.577334025316711
# var 4: 0.13270279280699082
# var 5: -1.2618287531600973
# var 6: -10.09022406701349
# var 7: 7.921492432475435
# var 8: -0.19312211083776187
# var 9: 5.49788774424191
# property NOT verified with max difference 2.4236046882335245
# overall time: 386.796443939209
# 4/39 | image index 34 ===========================================================================================
# start with optimization
# var 0: 8.112024699818681
# var 1: -6.377234395036952
# var 2: 2.5640865349991726
# var 3: -0.4729370796017811
# var 4: -5.745404977351727
# var 5: 0.27187268884657634
# var 6: 0.39773400273932946
# var 7: -3.810284771135782
# var 8: 4.163028154930789
# var 9: 0.07676813555237771
# property verified with max difference -3.9489965448878923
# overall time: 357.6073830127716
# 5/39 | image index 35 ===========================================================================================
# start with optimization
# var 0: -1.798713283706654
# var 1: 0.22605273714078855
# var 2: -1.295422742110345
# var 3: 0.9872692900375046
# var 4: -1.584027494513352
# var 5: 5.5779880863575535
# var 6: -0.6919818296870872
# var 7: -3.923331144000251
# var 8: 4.35093918563047
# var 9: -1.0929441350674693
# property verified with max difference -1.2270489007270833
# overall time: 437.7986671924591
# 6/39 | image index 36 ===========================================================================================
# start with optimization
# var 0: -3.8156026832297165
# var 1: 2.955741406728386
# var 2: 5.094145731621888
# var 3: -0.14226597840833932
# var 4: -0.20470780496622076
# var 5: 1.7448349279893414
# var 6: 7.562961699016473
# var 7: -4.711990901311129
# var 8: -0.1083737584354294
# var 9: -7.393200051864497
# property verified with max difference -2.468815967394585
# overall time: 395.4910445213318
# 7/39 | image index 37 ===========================================================================================
# start with optimization
# var 0: 9.033560415111786
# var 1: -5.583430696037922
# var 2: 4.581685814643657
# var 3: -0.3610500716847582
# var 4: -4.637396173332526
# var 5: -2.42853789311898
# var 6: 0.9217684015729244
# var 7: -0.7276887833219217
# var 8: 0.1677721084176369
# var 9: -1.0985768747478684
# property verified with max difference -4.4518746004681296
# overall time: 307.7447440624237
# 8/39 | image index 38 ===========================================================================================
# start with optimization
# var 0: -2.5522522698209027
# var 1: 0.4782263827262909
# var 2: 8.62400784690656
# var 3: 3.7292728479181303
# var 4: -1.9951894031055009
# var 5: -4.597797235627896
# var 6: -5.843483382405493
# var 7: 6.959913296996104
# var 8: -2.2400905337460646
# var 9: -0.8406757451189453
# property NOT verified with max difference 1.6640945499104554
# overall time: 352.7809057235718
# 9/39 | image index 39 ===========================================================================================
# start with optimization
# var 0: 1.3073366455485305
# var 1: -2.51673125012701
# var 2: 3.3426155689048516
# var 3: -2.6756386337672486
# var 4: 0.5926984008629885
# var 5: -0.7352566110482934
# var 6: 4.352540674157145
# var 7: 0.6720516797327045
# var 8: -3.2308193203628646
# var 9: -1.9066496082120485
# property verified with max difference -1.009925105252293
# overall time: 410.0448820590973

# %%
print(not_verified_index_snr)
# Out:
# [(30, 0), (32, 2), (33, 3), (38, 8)]

# %%
not_verified_index_snr = [(29, 8), (30, 0), (32, 2)]

# %%
group_size = 20
sample_count = 1000
sampling_method = "per_group_sampling"
net_size = [5, 1]
icnn_factory = ICNNFactory("logical", net_size, always_use_logical_layer=False)
#icnn_factory = ICNNFactory("standard", net_size, adapt_layer_for_init=True)
#icnn_factory = ICNNFactory("approx_max", net_size, maximum_function="SMU", function_parameter=0.3)

dhov_verifier_list = []
not_verified_index_dhov = []
sample_index = 0
round_index = 0
samples_to_verify_dhov = len(not_verified_index_snr)
for touple in not_verified_index_snr:
    sample_index = touple[0]
    round_index = touple[1]
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    #bounds_affine_out_snr, bounds_layer_out_snr = snr_verifier_list[round_index].bounds_affine_out, snr_verifier_list[round_index].bounds_layer_out
    bounds_affine_out_snr, bounds_layer_out_snr = None, None

    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_dhov-1, sample_index))


    overall_time = time.time()
    dhov_verifier = multidhov.MultiDHOV()
    dhov_verifier.start_verification(nn, torch_image, icnn_factory, group_size, eps=eps, icnn_epochs=200, init_affine_bounds=bounds_affine_out_snr, init_layer_bounds=bounds_layer_out_snr,
                                     icnn_batch_size=10000, sample_count=sample_count, sample_new=True, use_over_approximation=True, break_after=None,
                                     sample_over_input_space=False, sample_over_output_space=True, tighten_bounds=True,
                                     use_fixed_neurons_in_grouping=False, sampling_method=sampling_method, layers_as_snr=[], layers_as_milp=[3],
                                     force_inclusion_steps=3, preemptive_stop=True, even_gradient_training=False,
                                     keep_ambient_space=False, data_grad_descent_steps=0, opt_steps_gd=100,
                                     train_outer=False, print_training_loss=False, print_new_bounds=False,
                                     grouping_method="consecutive", group_num_multiplier=5, store_samples=False, print_optimization_steps=False, print_last_loss=False,
                                     should_plot="none", optimizer="SdLBFGS", init_network=True, adapt_lambda="included")


    dhov_verifier_list.append(dhov_verifier)

    dhov_model = dhov_verifier.nn_encoding_model.copy()
    dhov_model.update()
    dhov_out_vars = get_output_vars_dhov(dhov_model, output_size, number_layer)
    add_output_constraints(dhov_model, dhov_verifier.bounds_layer_out, label, dhov_out_vars, sovler_bound=float("inf"))
    successful_ver = optimize_model(dhov_model, dhov_out_vars)
    if not successful_ver:
        not_verified_index_dhov.append(sample_index)
    print("overall time: {}".format(time.time() - overall_time))
    round_index += 1
    sample_index += 1
# Out:
# 8/2 | image index 29 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 179
#     layer progress, group 1 of 4
#         time for sampling for one group: 0.17199993133544922
#         time for training: 6.409177541732788
#         actual verification time 5.932898283004761
#         time for verification: 6.153898000717163
#     layer progress, group 2 of 4
#         time for sampling for one group: 0.1060020923614502
#         time for training: 11.408236742019653
#         actual verification time 2.2807602882385254
#         time for verification: 2.590763807296753
#     layer progress, group 3 of 4
#         time for sampling for one group: 0.1959998607635498
#         time for training: 14.3070650100708
#         actual verification time 5.055915594100952
#         time for verification: 5.278916835784912
#     layer progress, group 4 of 4
#         time for sampling for one group: 0.11299920082092285
#         time for training: 9.26293396949768
#         actual verification time 0.7640314102172852
#         time for verification: 0.9720313549041748
#
# approximation of layer: 1
#     time for icnn_bound calculation: 39.567524909973145
#     number of fixed neurons for current layer: 173
#     layer progress, group 1 of 5
#         time for sampling for one group: 35.07283115386963
#         time for training: 12.604593276977539
#         actual verification time 27.50865864753723
#         time for verification: 27.853825569152832
#     layer progress, group 2 of 5
#         time for sampling for one group: 53.09227633476257
#         time for training: 10.147251605987549
#         actual verification time 13.226904153823853
#         time for verification: 13.592904090881348
#     layer progress, group 3 of 5
#         time for sampling for one group: 47.491872787475586
#         time for training: 28.577631950378418
#         actual verification time 15.570236206054688
#         time for verification: 15.812235116958618
#     layer progress, group 4 of 5
#         time for sampling for one group: 51.97442054748535
#         time for training: 22.695537328720093
#         actual verification time 15.711241006851196
#         time for verification: 16.19421076774597
#     layer progress, group 5 of 5
#         time for sampling for one group: 51.23438835144043
#         time for training: 31.976486444473267
#         actual verification time 1.4895482063293457
#         time for verification: 1.5735466480255127
#
# approximation of layer: 2
#     time for icnn_bound calculation: 202.0352964401245
#     number of fixed neurons for current layer: 189
#     layer progress, group 1 of 4
#         time for sampling for one group: 142.09853720664978
#         time for training: 14.59378170967102
#         actual verification time 29.736534118652344
#         time for verification: 30.01654601097107
#     layer progress, group 2 of 4
#         time for sampling for one group: 169.19944715499878
#         time for training: 13.92455506324768
#         actual verification time 129.5991175174713
#         time for verification: 129.8862750530243
#     layer progress, group 3 of 4
#         time for sampling for one group: 200.29434752464294
#         time for training: 12.9709632396698
#         actual verification time 57.33061599731445
#         time for verification: 57.532755613327026
#     layer progress, group 4 of 4
#         time for sampling for one group: 155.28412914276123
#         time for training: 28.819706439971924
#         actual verification time 10.760685920715332
#         time for verification: 10.960686922073364
#
# approximation of layer: 3
#     time for icnn_bound calculation: 649.0153188705444
#     number of fixed neurons for current layer: 155
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.014009475708007812
# done...
# var 0: -2.6089413991966968
# var 1: 1.8105975332129276
# var 2: 1.1077937578113792
# var 3: -2.0503171817251467
# var 4: 0.04559425243082027
# var 5: -0.9471785027471236
# var 6: -0.0663560898081349
# var 7: 0.817278549684396
# var 8: 3.4893359884640978
# var 9: -1.2537377745309197
# property NOT verified with max difference 2.672057438779702
# overall time: 2402.9813661575317
# 0/2 | image index 30 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 165
#     layer progress, group 1 of 5
#         time for sampling for one group: 0.11799931526184082
#         time for training: 6.658099174499512
#         actual verification time 4.415129661560059
#         time for verification: 4.640137434005737
#     layer progress, group 2 of 5
#         time for sampling for one group: 0.07900238037109375
#         time for training: 8.549784421920776
#         actual verification time 1.5410709381103516
#         time for verification: 1.8250720500946045
#     layer progress, group 3 of 5
#         time for sampling for one group: 0.10799765586853027
#         time for training: 7.217519044876099
#         actual verification time 1.249999761581421
#         time for verification: 1.5050513744354248
#     layer progress, group 4 of 5
#         time for sampling for one group: 0.11300110816955566
#         time for training: 5.020859479904175
#         actual verification time 2.247069835662842
#         time for verification: 2.512126922607422
#     layer progress, group 5 of 5
#         time for sampling for one group: 0.07500314712524414
#         time for training: 10.519875049591064
#         actual verification time 0.20299744606018066
#         time for verification: 0.4282827377319336
#
# approximation of layer: 1
#     time for icnn_bound calculation: 33.68922710418701
#     number of fixed neurons for current layer: 162
#     layer progress, group 1 of 5
#         time for sampling for one group: 27.770155668258667
#         time for training: 4.843988656997681
#         actual verification time 17.353512287139893
#         time for verification: 17.545516967773438
#     layer progress, group 2 of 5
#         time for sampling for one group: 31.427263259887695
#         time for training: 5.904975652694702
#         actual verification time 9.000145673751831
#         time for verification: 9.200167655944824
#     layer progress, group 3 of 5
#         time for sampling for one group: 34.89514660835266
#         time for training: 4.579911231994629
#         actual verification time 16.810022354125977
#         time for verification: 17.004026174545288
#     layer progress, group 4 of 5
#         time for sampling for one group: 65.31715393066406
#         time for training: 5.8335280418396
#         actual verification time 16.38339114189148
#         time for verification: 16.637377500534058
#     layer progress, group 5 of 5
#         time for sampling for one group: 36.688517808914185
#         time for training: 6.111529111862183
#         actual verification time 14.0341215133667
#         time for verification: 14.200119972229004
#
# approximation of layer: 2
#     time for icnn_bound calculation: 185.19886946678162
#     number of fixed neurons for current layer: 193
#     layer progress, group 1 of 4
#         time for sampling for one group: 183.83682513237
#         time for training: 12.944337606430054
#         actual verification time 36.27569890022278
#         time for verification: 36.66470503807068
#     layer progress, group 2 of 4
#         time for sampling for one group: 229.59481620788574
#         time for training: 5.942886590957642
#         actual verification time 81.17748188972473
#         time for verification: 81.39450120925903
#     layer progress, group 3 of 4
#         time for sampling for one group: 168.15492129325867
#         time for training: 10.536012172698975
#         actual verification time 42.12805485725403
#         time for verification: 42.33606553077698
#     layer progress, group 4 of 4
#         time for sampling for one group: 285.0605745315552
#         time for training: 32.18607783317566
#         actual verification time 5.558958053588867
#         time for verification: 5.734027624130249
#
# approximation of layer: 3
#     time for icnn_bound calculation: 607.2458581924438
#     number of fixed neurons for current layer: 173
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.009000539779663086
# done...
# var 0: -7.013379622940527
# var 1: 7.255488913945687
# var 2: 3.914705379728791
# var 3: 6.638236381111569
# var 4: -1.7845351943987344
# var 5: -2.8796745269177046
# var 6: -3.709211648936436
# var 7: 2.97500853817919
# var 8: 0.10726152896059293
# var 9: -2.3666950607092128
# property NOT verified with max difference 0.6172525328341175
# overall time: 2321.7916390895844
# 2/2 | image index 32 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 157
#     layer progress, group 1 of 5
#         time for sampling for one group: 0.2270035743713379
#         time for training: 18.97711420059204
#         actual verification time 1.2587153911590576
#         time for verification: 1.506723165512085
#     layer progress, group 2 of 5
#         time for sampling for one group: 0.13499903678894043
#         time for training: 9.290328741073608
#         actual verification time 1.2019860744476318
#         time for verification: 1.4180667400360107
#     layer progress, group 3 of 5
#         time for sampling for one group: 0.08999323844909668
#         time for training: 5.989277362823486
#         actual verification time 1.9881041049957275
#         time for verification: 2.23709774017334
#     layer progress, group 4 of 5
#         time for sampling for one group: 0.10789990425109863
#         time for training: 6.140979051589966
#         actual verification time 6.008275985717773
#         time for verification: 6.262273550033569
#     layer progress, group 5 of 5
#         time for sampling for one group: 0.15800094604492188
#         time for training: 9.595933437347412
#         actual verification time 1.1865644454956055
#         time for verification: 1.438556432723999
#
# approximation of layer: 1
#     time for icnn_bound calculation: 49.615344285964966
#     number of fixed neurons for current layer: 146
#     layer progress, group 1 of 6
#         time for sampling for one group: 45.143338441848755
#         time for training: 5.814406871795654
#         actual verification time 28.13773488998413
#         time for verification: 28.390403032302856
#     layer progress, group 2 of 6
#         time for sampling for one group: 44.042011737823486
#         time for training: 8.40955138206482
#         actual verification time 42.21506857872009
#         time for verification: 42.48407554626465
#     layer progress, group 3 of 6
#         time for sampling for one group: 36.72644019126892
#         time for training: 21.52884578704834
#         actual verification time 11.128877401351929
#         time for verification: 11.440890789031982
#     layer progress, group 4 of 6
#         time for sampling for one group: 73.69725847244263
#         time for training: 14.002431631088257
#         actual verification time 40.601351261138916
#         time for verification: 40.87341356277466
#     layer progress, group 5 of 6
#         time for sampling for one group: 67.83518075942993
#         time for training: 11.45261836051941
#         actual verification time 17.822869300842285
#         time for verification: 18.099432706832886
#     layer progress, group 6 of 6
#         time for sampling for one group: 47.62730693817139
#         time for training: 11.030954599380493
#         actual verification time 4.825137615203857
#         time for verification: 4.995150566101074
#
# approximation of layer: 2
#     time for icnn_bound calculation: 291.70887660980225
#     number of fixed neurons for current layer: 148
#     layer progress, group 1 of 6
#         time for sampling for one group: 234.99742555618286
#         time for training: 5.344151973724365
#         actual verification time 155.27515077590942
#         time for verification: 155.48515844345093
#     layer progress, group 2 of 6
#         time for sampling for one group: 361.6583173274994
#         time for training: 6.498053789138794
#         actual verification time 66.15905666351318
#         time for verification: 66.44205141067505
#     layer progress, group 3 of 6
#         time for sampling for one group: 276.16518473625183
#         time for training: 6.858504056930542
#         actual verification time 103.97824764251709
#         time for verification: 104.18725061416626
#     layer progress, group 4 of 6
#         time for sampling for one group: 206.59066200256348
#         time for training: 8.906986951828003
#         actual verification time 17.378893613815308
#         time for verification: 17.584917545318604
#     layer progress, group 5 of 6
#         time for sampling for one group: 249.80117440223694
#         time for training: 7.400858640670776
#         actual verification time 73.55009937286377
#         time for verification: 73.85609674453735
#     layer progress, group 6 of 6
#         time for sampling for one group: 168.32827234268188
#         time for training: 18.145628690719604
#         actual verification time 12.13612151145935
#         time for verification: 12.30713415145874
#
# approximation of layer: 3
#     time for icnn_bound calculation: 541.9836494922638
#     number of fixed neurons for current layer: 127
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.010999202728271484
# done...
# var 0: 0.5542264000755752
# var 1: -0.46336794309806884
# var 2: 5.11810128204058
# var 3: -1.9668069880185035
# var 4: -0.18398362937748303
# var 5: 0.12166670675887392
# var 6: 6.293241995512132
# var 7: 0.2858242596022915
# var 8: -4.583089106705683
# var 9: -5.270330709280274
# property verified with max difference -1.1751407133089806
# overall time: 3788.5025491714478
