# %%
import torch
import time
from script.NeuralNets.Networks import SequentialNN
from script.settings import device, data_type
import script.DHOV.MultiDHOV as multidhov
from script.Verification.Verifier import SingleNeuronVerifier, MILPVerifier
import gurobipy as grp
from torchvision.datasets import MNIST
from torchvision.transforms import Compose, ToTensor, Normalize
from script.NeuralNets.ICNNFactory import ICNNFactory
import matplotlib.pyplot as plt
from script import eval

# %%
def add_output_constraints(model, nn_layer_out_bounds, label, output_vars, sovler_bound=1e-3):
    out_lb = nn_layer_out_bounds[-1][0]
    out_ub = nn_layer_out_bounds[-1][1]
    difference_lb = out_lb - out_ub[label]
    difference_ub = out_ub - out_lb[label]
    difference_lb = difference_lb.tolist()
    difference_ub = difference_ub.tolist()
    difference_lb.pop(label)
    difference_ub.pop(label)
    min_diff = min(difference_lb)
    max_diff = max(difference_ub)

    difference = model.addVars(9, lb=difference_lb, ub=difference_ub, name="diff_var")
    model.addConstrs((difference[i] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(0, label)), name="diff_const0")
    model.addConstrs((difference[i - 1] == output_vars.tolist()[i] - output_vars.tolist()[label] for i in range(label + 1, 10)), name="diff_const1")

    max_var = model.addVar(lb=min_diff, ub=max_diff, name="max_var")
    model.addConstr(max_var == grp.max_(difference))

    if sovler_bound != None:
        model.setParam("BestObjStop", sovler_bound)

    model.update()
    model.setObjective(max_var, grp.GRB.MAXIMIZE)

# %%
def get_output_vars_snv_milp(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("affine_var{}[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def get_output_vars_dhov(model, output_size, output_layer_index):
    output_vars = []
    for i in range(output_size):
        output_vars.append(model.getVarByName("output_layer_[{}]_[{}]".format(output_layer_index, i)))
    output_vars = grp.MVar.fromlist(output_vars)
    return output_vars

# %%
def optimize_model(model, output_vars):
    start = time.time()
    model.update()
    model.optimize()
    if model.Status == grp.GRB.OPTIMAL or model.Status == grp.GRB.USER_OBJ_LIMIT:
        for i, var in enumerate(output_vars.tolist()):
            print("var {}: {}".format(i, var.getAttr("x")))
        max_var = model.getVarByName("max_var").getAttr("x")
        if max_var < 0:
            print("property verified with max difference {}".format(max_var))
            return True
        else:
             print("property NOT verified with max difference {}".format(max_var))
             return False

    elif model.Status == grp.GRB.INFEASIBLE:
        print("model infeasible")

        model.computeIIS()
        print("constraint")
        all_constr = model.getConstrs()

        for const in all_constr:
            if const.IISConstr:
                print("{}".format(const))

        print("lower bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISLB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

        print("upper bound")
        all_var = model.getVars()
        for var in all_var:
            if var.IISUB:
                print("{}, lb: {}, ub: {}".format(var, var.getAttr("lb"), var.getAttr("ub")))

    print("time to optimize: {}".format(time.time() - start))
    return False

# %%
transform = Compose([ToTensor(),  Normalize(0.5, 0.5)])
training_data = MNIST(root="../../mnist", train=True, download=True, transform=transform)

nn = SequentialNN([28 * 28 * 1, 256, 256, 256, 256, 10])
nn.load_state_dict(torch.load("../../mnist_fc 4x256.pth", map_location=torch.device('cpu')), strict=False)
parameter_list = list(nn.parameters())
output_size = 10
number_layer = (len(parameter_list) - 2) // 2

eps = 0.026
samples_to_verify_count = 20

# %% [markdown]
# DHOV

# %% [markdown]
# SNR

# %%
snr_verifier_list = []
not_verified_index_snr = []
sample_index = 10
round_index = 0
while sample_index < samples_to_verify_count:
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    simple_bounds_affine_out, simple_bounds_layer_out = nn.calculate_box_bounds([input_flattened.add(-eps), input_flattened.add(eps)])

    if not torch.argmax(nn(torch_image)).item() == label:
        sample_index += 1
        continue
    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_count-1, sample_index))

    overall_time = time.time()
    snv_verifier = SingleNeuronVerifier(nn, torch_image, eps, print_log=False, print_new_bounds=False, optimize_bounds=True)
    snv_verifier.generate_constraints_for_net()
    snr_verifier_list.append(snv_verifier)
    snv_model = snv_verifier.model.copy()
    snv_model.update()
    snv_out_vars = get_output_vars_snv_milp(snv_model, output_size, number_layer * 2)
    add_output_constraints(snv_model, simple_bounds_layer_out, label, snv_out_vars, sovler_bound=None)

    print("start with optimization")
    successful_ver = optimize_model(snv_model, snv_out_vars)
    if not successful_ver:
        not_verified_index_snr.append((sample_index, round_index))
    print("overall time: {}".format(time.time() - overall_time))

    round_index += 1
    sample_index += 1
# Out:
# 0/19 | image index 10 ===========================================================================================
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-11-12
# start with optimization
# var 0: -6.341963698711135
# var 1: 2.3206259344537425
# var 2: -3.5247874229017135
# var 3: 11.62470320441655
# var 4: -3.1074830622462155
# var 5: 3.372600872100561
# var 6: -9.852146671366304
# var 7: -3.7789712080366424
# var 8: 5.07694529221069
# var 9: 6.876585037968928
# property verified with max difference -4.748118166447622
# overall time: 271.8817298412323
# 1/19 | image index 11 ===========================================================================================
# start with optimization
# var 0: -1.7752559866789968
# var 1: 0.3230365739245782
# var 2: 1.0811832945999749
# var 3: -0.46611834673174446
# var 4: -1.2545000639238326
# var 5: 5.1229645251930505
# var 6: 2.1846138681199596
# var 7: -5.335696532531084
# var 8: 4.827707911330914
# var 9: -4.076696478113953
# property verified with max difference -0.2952566138621364
# overall time: 397.7765951156616
# 2/19 | image index 12 ===========================================================================================
# start with optimization
# var 0: -8.30880681905814
# var 1: 6.391152052804396
# var 2: 0.252209262599731
# var 3: 13.915145258975409
# var 4: -4.099252197370591
# var 5: 1.7303250797983178
# var 6: -9.493983582154899
# var 7: -0.5428599010314006
# var 8: 2.2476876044448506
# var 9: 1.8406450215732963
# property verified with max difference -7.523993206171013
# overall time: 323.43767738342285
# 3/19 | image index 13 ===========================================================================================
# start with optimization
# var 0: -0.4965534787531416
# var 1: -3.1858927189999795
# var 2: 0.7707390779335324
# var 3: -4.518826401583911
# var 4: 4.585275553810719
# var 5: 1.2203771705712425
# var 6: 7.837198206414969
# var 7: -4.591788698032931
# var 8: 0.21376177332853175
# var 9: -3.3224962814836045
# property verified with max difference -3.251922652604235
# overall time: 336.9228012561798
# 4/19 | image index 14 ===========================================================================================
# start with optimization
# var 0: -6.295664571609035
# var 1: 6.570190806256789
# var 2: 0.38879179821250265
# var 3: 1.6511283343036824
# var 4: -2.6731416645518715
# var 5: 0.20432726081690067
# var 6: -2.016806532514276
# var 7: -1.4651433644820928
# var 8: 6.766339694493474
# var 9: -1.0322007466578276
# property NOT verified with max difference 0.19614888823668508
# overall time: 450.3305194377899
# 5/19 | image index 15 ===========================================================================================
# start with optimization
# var 0: -1.7942505094052255
# var 1: -3.4253045934899156
# var 2: 0.29732158511785123
# var 3: -0.4910394896055639
# var 4: 0.3035720536157953
# var 5: -0.8047562743818837
# var 6: -9.247338181121261
# var 7: 8.62759580760699
# var 8: 0.56003284078189
# var 9: 5.685160994567116
# property verified with max difference -2.942434813039874
# overall time: 326.0772476196289
# 6/19 | image index 16 ===========================================================================================
# start with optimization
# var 0: 0.5981892820037418
# var 1: -3.0534187696328345
# var 2: 6.010549256682912
# var 3: 1.4137375954189215
# var 4: 0.1646943552220712
# var 5: -4.719488155008772
# var 6: -4.421587448469436
# var 7: 4.828055915406914
# var 8: -0.9175825456656508
# var 9: 0.4977578076373428
# property verified with max difference -1.1824933412759981
# overall time: 566.8695657253265
# 7/19 | image index 17 ===========================================================================================
# start with optimization
# var 0: -6.554680794635432
# var 1: 4.513047222792624
# var 2: -0.1419073144281242
# var 3: 2.5922605101654863
# var 4: -2.282917485914547
# var 5: 1.068231113120385
# var 6: -5.817206070502701
# var 7: -1.63160308532302
# var 8: 8.145414154350624
# var 9: 1.7690188412993066
# property verified with max difference -3.632366931558
# overall time: 312.33863139152527
# 8/19 | image index 18 ===========================================================================================
# start with optimization
# var 0: -1.233981694684343
# var 1: -1.2226454446990607
# var 2: -1.9710946225955253
# var 3: 1.6745985415427116
# var 4: -2.0422324602238158
# var 5: 7.3896716714771875
# var 6: 0.35067683842742614
# var 7: -4.632199980409346
# var 8: 1.388815447218417
# var 9: 0.25282427592133505
# property NOT verified with max difference 7.038994833049761
# overall time: 667.6538949012756
# 9/19 | image index 19 ===========================================================================================
# start with optimization
# var 0: -7.184901213452987
# var 1: 2.981079365235166
# var 2: -2.3588341439578766
# var 3: 6.7137486370928645
# var 4: -1.0155757081693029
# var 5: 2.6605151909041442
# var 6: -9.230592248421521
# var 7: 1.887302825523788
# var 8: 2.991990172531702
# var 9: 4.544476063268137
# property NOT verified with max difference 2.1692725738247276
# overall time: 430.9580512046814

# %%
print(not_verified_index_snr)
# Out:
# [(14, 4), (18, 8), (19, 9)]

# %%
group_size = 20
sample_count = 1000
sampling_method = "per_group_sampling"
net_size = [5, 1]
icnn_factory = ICNNFactory("logical", net_size, always_use_logical_layer=False)
#icnn_factory = ICNNFactory("standard", net_size, adapt_layer_for_init=True)
#icnn_factory = ICNNFactory("approx_max", net_size, maximum_function="SMU", function_parameter=0.3)

dhov_verifier_list = []
not_verified_index_dhov = []
sample_index = 0
round_index = 0
samples_to_verify_dhov = len(not_verified_index_snr)
for touple in not_verified_index_snr:
    sample_index = touple[0]
    round_index = touple[1]
    image, label = training_data.__getitem__(sample_index)
    torch_image = torch.unsqueeze(image, 0).to(dtype=data_type).to(device)
    input_flattened = torch.flatten(torch_image)
    #bounds_affine_out_snr, bounds_layer_out_snr = snr_verifier_list[round_index].bounds_affine_out, snr_verifier_list[round_index].bounds_layer_out
    bounds_affine_out_snr, bounds_layer_out_snr = None, None

    print("{}/{} | image index {} ===========================================================================================".format(round_index, samples_to_verify_dhov-1, sample_index))


    overall_time = time.time()
    dhov_verifier = multidhov.MultiDHOV()
    dhov_verifier.start_verification(nn, torch_image, icnn_factory, group_size, eps=eps, icnn_epochs=200, init_affine_bounds=bounds_affine_out_snr, init_layer_bounds=bounds_layer_out_snr,
                                     icnn_batch_size=10000, sample_count=sample_count, sample_new=True, use_over_approximation=True, break_after=None,
                                     sample_over_input_space=False, sample_over_output_space=True, tighten_bounds=True,
                                     use_fixed_neurons_in_grouping=False, sampling_method=sampling_method, layers_as_snr=[], layers_as_milp=[3],
                                     force_inclusion_steps=3, preemptive_stop=True, even_gradient_training=False,
                                     keep_ambient_space=False, data_grad_descent_steps=0, opt_steps_gd=100,
                                     train_outer=False, print_training_loss=False, print_new_bounds=False,
                                     grouping_method="consecutive", group_num_multiplier=5, store_samples=False, print_optimization_steps=False, print_last_loss=False,
                                     should_plot="none", optimizer="SdLBFGS", init_network=True, adapt_lambda="included")


    dhov_verifier_list.append(dhov_verifier)

    dhov_model = dhov_verifier.nn_encoding_model.copy()
    dhov_model.update()
    dhov_out_vars = get_output_vars_dhov(dhov_model, output_size, number_layer)
    add_output_constraints(dhov_model, dhov_verifier.bounds_layer_out, label, dhov_out_vars, sovler_bound=float("inf"))
    successful_ver = optimize_model(dhov_model, dhov_out_vars)
    if not successful_ver:
        not_verified_index_dhov.append(sample_index)
    print("overall time: {}".format(time.time() - overall_time))
    round_index += 1
    sample_index += 1
# Out:
# 4/2 | image index 14 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 168
#     layer progress, group 1 of 5
#         time for sampling for one group: 0.08500242233276367
#         time for training: 4.906861066818237
#         actual verification time 0.7750320434570312
#         time for verification: 0.9750330448150635
#     layer progress, group 2 of 5
#         time for sampling for one group: 0.10500049591064453
#         time for training: 6.307177305221558
#         actual verification time 1.5591530799865723
#         time for verification: 1.7911567687988281
#     layer progress, group 3 of 5
#         time for sampling for one group: 0.1340034008026123
#         time for training: 9.188636541366577
#         actual verification time 18.94533348083496
#         time for verification: 19.203858375549316
#     layer progress, group 4 of 5
#         time for sampling for one group: 0.11799955368041992
#         time for training: 13.152701377868652
#         actual verification time 2.780242443084717
#         time for verification: 3.0503084659576416
#     layer progress, group 5 of 5
#         time for sampling for one group: 0.06000089645385742
#         time for training: 17.09842014312744
#         actual verification time 0.16399860382080078
#         time for verification: 0.32700157165527344
#
# approximation of layer: 1
#     time for icnn_bound calculation: 42.62154006958008
#     number of fixed neurons for current layer: 158
#     layer progress, group 1 of 5
#         time for sampling for one group: 51.730406284332275
#         time for training: 13.051804780960083
#         actual verification time 47.36705684661865
#         time for verification: 47.55506467819214
#     layer progress, group 2 of 5
#         time for sampling for one group: 49.0583758354187
#         time for training: 19.01864266395569
#         actual verification time 25.79380512237549
#         time for verification: 26.113823175430298
#     layer progress, group 3 of 5
#         time for sampling for one group: 52.391499042510986
#         time for training: 25.83461046218872
#         actual verification time 18.128419399261475
#         time for verification: 18.383938789367676
#     layer progress, group 4 of 5
#         time for sampling for one group: 52.35906720161438
#         time for training: 14.110141038894653
#         actual verification time 22.538689851760864
#         time for verification: 22.780694723129272
#     layer progress, group 5 of 5
#         time for sampling for one group: 37.69074821472168
#         time for training: 13.521989822387695
#         actual verification time 11.217790603637695
#         time for verification: 11.408788681030273
#
# approximation of layer: 2
#     time for icnn_bound calculation: 219.76388955116272
#     number of fixed neurons for current layer: 185
#     layer progress, group 1 of 4
#         time for sampling for one group: 187.84742164611816
#         time for training: 7.358921527862549
#         actual verification time 33.915953159332275
#         time for verification: 34.114973068237305
#     layer progress, group 2 of 4
#         time for sampling for one group: 245.90465569496155
#         time for training: 16.60850501060486
#         actual verification time 50.73144173622131
#         time for verification: 50.97544312477112
#     layer progress, group 3 of 4
#         time for sampling for one group: 232.3267629146576
#         time for training: 17.24054789543152
#         actual verification time 26.89451241493225
#         time for verification: 27.08452320098877
#     layer progress, group 4 of 4
#         time for sampling for one group: 251.15583109855652
#         time for training: 11.578593015670776
#         actual verification time 6.979110479354858
#         time for verification: 7.164110422134399
#
# approximation of layer: 3
#     time for icnn_bound calculation: 720.1458079814911
#     number of fixed neurons for current layer: 155
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.00800180435180664
# done...
# var 0: -7.052068152207175
# var 1: 7.783492227396897
# var 2: 0.06633155777711863
# var 3: 1.6661946378026675
# var 4: -2.433858994125064
# var 5: 0.07738319821584039
# var 6: -1.9526665632068045
# var 7: -1.4592697765709257
# var 8: 6.620420197580712
# var 9: -1.0849321946540318
# property verified with max difference -1.1630720298161847
# overall time: 2705.921046972275
# 8/2 | image index 18 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 146
#     layer progress, group 1 of 6
#         time for sampling for one group: 0.12600302696228027
#         time for training: 7.184310436248779
#         actual verification time 1.8129503726959229
#         time for verification: 2.0539989471435547
#     layer progress, group 2 of 6
#         time for sampling for one group: 0.1379995346069336
#         time for training: 8.2005774974823
#         actual verification time 5.379414081573486
#         time for verification: 5.691436290740967
#     layer progress, group 3 of 6
#         time for sampling for one group: 0.46699953079223633
#         time for training: 9.0355064868927
#         actual verification time 1.9505460262298584
#         time for verification: 2.165545701980591
#     layer progress, group 4 of 6
#         time for sampling for one group: 0.08999180793762207
#         time for training: 5.264598608016968
#         actual verification time 1.5040662288665771
#         time for verification: 1.723067283630371
#     layer progress, group 5 of 6
#         time for sampling for one group: 0.10000419616699219
#         time for training: 5.8986756801605225
#         actual verification time 2.2940409183502197
#         time for verification: 2.5210392475128174
#     layer progress, group 6 of 6
#         time for sampling for one group: 0.04199790954589844
#         time for training: 11.934371709823608
#         actual verification time 0.32359957695007324
#         time for verification: 0.4535987377166748
#
# approximation of layer: 1
#     time for icnn_bound calculation: 51.505189657211304
#     number of fixed neurons for current layer: 149
#     layer progress, group 1 of 6
#         time for sampling for one group: 35.42321848869324
#         time for training: 10.858416080474854
#         actual verification time 5.477458238601685
#         time for verification: 5.691537618637085
#     layer progress, group 2 of 6
#         time for sampling for one group: 41.16442894935608
#         time for training: 22.715117931365967
#         actual verification time 28.290889978408813
#         time for verification: 28.61188817024231
#     layer progress, group 3 of 6
#         time for sampling for one group: 41.5733060836792
#         time for training: 5.726944446563721
#         actual verification time 16.61103630065918
#         time for verification: 16.815572500228882
#     layer progress, group 4 of 6
#         time for sampling for one group: 35.13489103317261
#         time for training: 5.453303337097168
#         actual verification time 63.30985403060913
#         time for verification: 63.518874168395996
#     layer progress, group 5 of 6
#         time for sampling for one group: 37.626953125
#         time for training: 12.478374719619751
#         actual verification time 42.208430767059326
#         time for verification: 42.68144679069519
#     layer progress, group 6 of 6
#         time for sampling for one group: 71.70491600036621
#         time for training: 58.37802529335022
#         actual verification time 3.7000410556793213
#         time for verification: 3.8010404109954834
#
# approximation of layer: 2
#     time for icnn_bound calculation: 308.03794384002686
#     number of fixed neurons for current layer: 143
#     layer progress, group 1 of 6
#         time for sampling for one group: 344.8401777744293
#         time for training: 7.670443773269653
#         actual verification time 31.4572274684906
#         time for verification: 31.661851406097412
#     layer progress, group 2 of 6
#         time for sampling for one group: 265.6059410572052
#         time for training: 8.689532041549683
#         actual verification time 98.54940056800842
#         time for verification: 98.75340986251831
#     layer progress, group 3 of 6
#         time for sampling for one group: 249.11121463775635
#         time for training: 7.533609867095947
#         actual verification time 74.29737949371338
#         time for verification: 74.51392483711243
#     layer progress, group 4 of 6
#         time for sampling for one group: 299.61728143692017
#         time for training: 18.081317901611328
#         actual verification time 96.21391987800598
#         time for verification: 96.55992007255554
#     layer progress, group 5 of 6
#         time for sampling for one group: 351.3945310115814
#         time for training: 8.337910175323486
#         actual verification time 29.429544925689697
#         time for verification: 29.651556491851807
#     layer progress, group 6 of 6
#         time for sampling for one group: 258.9675476551056
#         time for training: 13.63983416557312
#         actual verification time 12.64652681350708
#         time for verification: 12.824532985687256
#
# approximation of layer: 3
#     time for icnn_bound calculation: 1265.6441071033478
#     number of fixed neurons for current layer: 129
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.011999368667602539
# done...
# var 0: -1.0366807504990787
# var 1: -1.2716823158385566
# var 2: -2.411511399314416
# var 3: 1.288685808303491
# var 4: -1.6212664793162246
# var 5: 6.932139800451151
# var 6: 1.7675322560176798
# var 7: -5.819979761240281
# var 8: 1.961088106655547
# var 9: 0.05871947523019849
# property NOT verified with max difference 5.164607544433471
# overall time: 4585.772077322006
# 9/2 | image index 19 ===========================================================================================
#
# approximation of layer: 0
#     number of fixed neurons for current layer: 159
#     layer progress, group 1 of 5
#         time for sampling for one group: 0.10700201988220215
#         time for training: 5.50159764289856
#         actual verification time 2.4492385387420654
#         time for verification: 2.639249801635742
#     layer progress, group 2 of 5
#         time for sampling for one group: 0.08099508285522461
#         time for training: 6.9156341552734375
#         actual verification time 1.0241239070892334
#         time for verification: 1.2151339054107666
#     layer progress, group 3 of 5
#         time for sampling for one group: 0.06799721717834473
#         time for training: 7.154696464538574
#         actual verification time 1.1749992370605469
#         time for verification: 1.3739984035491943
#     layer progress, group 4 of 5
#         time for sampling for one group: 0.08600139617919922
#         time for training: 5.347445726394653
#         actual verification time 3.725142240524292
#         time for verification: 3.917149782180786
#     layer progress, group 5 of 5
#         time for sampling for one group: 0.07599711418151855
#         time for training: 4.712460041046143
#         actual verification time 0.6221082210540771
#         time for verification: 0.798119068145752
#
# approximation of layer: 1
#     time for icnn_bound calculation: 38.323822259902954
#     number of fixed neurons for current layer: 171
#     layer progress, group 1 of 5
#         time for sampling for one group: 72.23680448532104
#         time for training: 16.00940489768982
#         actual verification time 8.923449277877808
#         time for verification: 9.09352445602417
#     layer progress, group 2 of 5
#         time for sampling for one group: 26.811792612075806
#         time for training: 4.621552467346191
#         actual verification time 15.533982038497925
#         time for verification: 15.697046279907227
#     layer progress, group 3 of 5
#         time for sampling for one group: 26.959471225738525
#         time for training: 6.341098308563232
#         actual verification time 19.691144704818726
#         time for verification: 19.87115240097046
#     layer progress, group 4 of 5
#         time for sampling for one group: 26.913933992385864
#         time for training: 4.417547702789307
#         actual verification time 173.82881045341492
#         time for verification: 174.00282192230225
#     layer progress, group 5 of 5
#         time for sampling for one group: 27.258873462677002
#         time for training: 9.186041831970215
#         actual verification time 2.2115211486816406
#         time for verification: 2.3095273971557617
#
# approximation of layer: 2
#     time for icnn_bound calculation: 122.41300201416016
#     number of fixed neurons for current layer: 173
#     layer progress, group 1 of 5
#         time for sampling for one group: 113.20028018951416
#         time for training: 8.924916744232178
#         actual verification time 19.055720329284668
#         time for verification: 19.222726106643677
#     layer progress, group 2 of 5
#         time for sampling for one group: 104.87544798851013
#         time for training: 5.0654296875
#         actual verification time 47.907879114151
#         time for verification: 48.07388401031494
#     layer progress, group 3 of 5
#         time for sampling for one group: 150.75020933151245
#         time for training: 5.720063924789429
#         actual verification time 82.21774578094482
#         time for verification: 82.4137556552887
#     layer progress, group 4 of 5
#         time for sampling for one group: 107.57099461555481
#         time for training: 3.8899598121643066
#         actual verification time 22.87496542930603
#         time for verification: 23.027572870254517
#     layer progress, group 5 of 5
#         time for sampling for one group: 106.06928586959839
#         time for training: 6.69562292098999
#         actual verification time 2.3195719718933105
#         time for verification: 2.4112708568573
#
# approximation of layer: 3
#     time for icnn_bound calculation: 267.85276556015015
#     number of fixed neurons for current layer: 167
#     encode layer 3 as MILP
# time for icnn_bound calculation (last layer):0.004999637603759766
# done...
# var 0: -6.8425537166555745
# var 1: 1.4113428873288534
# var 2: -4.145893006417666
# var 3: 3.3149691250455176
# var 4: 0.8691126975425085
# var 5: 2.841457770620315
# var 6: -7.685132130165417
# var 7: -1.1746835305441472
# var 8: 6.67636036339831
# var 9: 5.867837275321309
# property NOT verified with max difference 0.8085230880770019
# overall time: 1737.01109457016
